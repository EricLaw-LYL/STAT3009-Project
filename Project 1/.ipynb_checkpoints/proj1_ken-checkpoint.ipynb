# %% [markdown]
# # STAT3009 Project 1
# # SID:1155152095(T = 2095)
# # Name: Lam Wai Chiu

# %% [markdown]
# ## Import package

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
import itertools
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

# %% [markdown]
# ## Load the developed methods

# %%
def rmse(true, pred):
	return np.sqrt(np.mean((pred - true)**2))

def print_T(t,temp_test_pair,pred_rating):
	print('test_pair:' ,temp_test_pair[t])
	print('pred_rating:',pred_rating[t])

def print_top5(t,temp_test_pair,pred):
	user_index=np.where(temp_test_pair[:,0]==temp_test_pair[t,0])[0]
	item_index=pred_rating[user_index].argsort()[-5:][::-1]
	list1=temp_test_pair[user_index,1][item_index]
	list2=pred_rating[user_index][item_index]
	result = pd.DataFrame(list(zip(list1, list2)), columns =['item', 'rating'])
	print(result.sort_values(by='rating', ascending=False).to_string(index=False))

def get_id(id,temp_id):
	temp=id
	uniq=np.unique(temp_id)
	for i in range(len(id)):
		temp[i]=np.where(id[i]==uniq)[0][0]
	return temp


class LFM(object):

    def __init__(self, n_user, n_item, lam=.001, K=10, iterNum=10, tol=1e-4, verbose=1):
        self.P = np.random.randn(n_user, K)
        self.Q = np.random.randn(n_item, K)
        # self.index_item = []
        # self.index_user = []
        self.n_user = n_user
        self.n_item = n_item
        self.lam = lam
        self.K = K
        self.iterNum = iterNum
        self.tol = tol
        self.verbose = verbose

    def fit(self, train_pair, train_rating):
        diff, tol = 1., self.tol
        n_user, n_item, n_obs = self.n_user, self.n_item, len(train_pair)
        K, iterNum, lam = self.K, self.iterNum, self.lam
        ## store user/item index set
        self.index_item = [np.where(train_pair[:,1] == i)[0] for i in range(n_item)]
        self.index_user = [np.where(train_pair[:,0] == u)[0] for u in range(n_user)]
        if self.verbose:
            print('Fitting Reg-LFM: K: %d, lam: %.5f' %(K, lam))
        for i in range(iterNum):
            ## item update
            score_old = self.rmse(test_pair=train_pair, test_rating=train_rating)
            for item_id in range(n_item):
                index_item_tmp = self.index_item[item_id]
                if len(index_item_tmp) == 0:
                    self.Q[item_id,:] = 0.
                    continue
                sum_pu, sum_matrix = np.zeros((K)), np.zeros((K, K))
                for record_ind in index_item_tmp:
                    ## double-check
                    if item_id != train_pair[record_ind][1]:
                        raise ValueError('the item_id is waring in updating Q!')
                    user_id, rating_tmp = train_pair[record_ind][0], train_rating[record_ind]
                    sum_matrix = sum_matrix + np.outer(self.P[user_id,:], self.P[user_id,:])
                    sum_pu = sum_pu + rating_tmp * self.P[user_id,:]                    
                self.Q[item_id,:] = np.dot(np.linalg.inv(sum_matrix + lam*n_obs*np.identity(K)), sum_pu)
            
            for user_id in range(n_user):
                index_user_tmp = self.index_user[user_id]
                if len(index_user_tmp) == 0:
                    self.P[user_id,:] = 0.
                    continue
                sum_pu, sum_matrix = np.zeros((K)), np.zeros((K, K))
                for record_ind in index_user_tmp:
                    ## double-check
                    if user_id != train_pair[record_ind][0]:
                        raise ValueError('the user_id is waring in updating P!')
                    item_id, rating_tmp = train_pair[record_ind][1], train_rating[record_ind]
                    sum_matrix = sum_matrix + np.outer(self.Q[item_id,:], self.Q[item_id,:])
                    sum_pu = sum_pu + rating_tmp * self.Q[item_id,:]                    
                self.P[user_id,:] = np.dot(np.linalg.inv(sum_matrix + lam*n_obs*np.identity(K)), sum_pu)
            # compute the new rmse score
            score_new = self.rmse(test_pair=train_pair, test_rating=train_rating)
            diff = abs(score_new - score_old) / score_old
            if self.verbose:
                print("Reg-LFM: ite: %d; diff: %.3f RMSE: %.3f" %(i, diff, score_new))
            if(diff < tol):
                break

    def predict(self, test_pair):
        # predict ratings for user-item pairs
        pred_rating = [np.dot(self.P[line[0]], self.Q[line[1]]) for line in test_pair]
        return np.array(pred_rating)
    
    def rmse(self, test_pair, test_rating):
        # report the rmse for the fitted `LFM`
        pred_rating = self.predict(test_pair=test_pair)
        return np.sqrt( np.mean( (pred_rating - test_rating)**2) )

# %%
# baseline methods
class glb_mean(object):
	def __init__(self):
		self.glb_mean = 0
	
	def fit(self, train_ratings):
		self.glb_mean = np.mean(train_ratings)
	
	def predict(self, test_pair):
		pred = np.ones(len(test_pair))
		pred = pred*self.glb_mean
		return pred

class user_mean(object):
	def __init__(self, n_user):
		self.n_user = n_user
		self.glb_mean = 0.
		self.user_mean = np.zeros(n_user)
	
	def fit(self, train_pair, train_ratings):
		self.glb_mean = train_ratings.mean()
		for u in range(self.n_user):
			ind_train = np.where(train_pair[:,0] == u)[0]
			if len(ind_train) == 0:
				self.user_mean[u] = self.glb_mean
			else:
				self.user_mean[u] = train_ratings[ind_train].mean()
	
	def predict(self, test_pair):
		pred = np.ones(len(test_pair))*self.glb_mean
		j = 0
		for row in test_pair:
			user_tmp, item_tmp = row[0], row[1]
			pred[j] = self.user_mean[user_tmp]
			j = j + 1
		return pred

class item_mean(object):
	def __init__(self, n_item):
		self.n_item = n_item
		self.glb_mean = 0.
		self.item_mean = np.zeros(n_item)
	
	def fit(self, train_pair, train_ratings):
		self.glb_mean = train_ratings.mean()
		for i in range(self.n_item):
			ind_train = np.where(train_pair[:,1] == i)[0]
			if len(ind_train) == 0:
				self.item_mean[i] = self.glb_mean
			else:
				self.item_mean[i] = train_ratings[ind_train].mean()
	
	def predict(self, test_pair):
		pred = np.ones(len(test_pair))*self.glb_mean
		j = 0
		for row in test_pair:
			user_tmp, item_tmp = row[0], row[1]
			pred[j] = self.item_mean[item_tmp]
			j = j + 1
		return pred

# %%
class LFM_CV(object):

	def __init__(self, n_user, n_item, cv=5,
				lams=[.000001,.0001,.001,.01], 
				Ks=[3,5,10,20], 
				iterNum=10, tol=1e-4):
		# self.index_item = []
		# self.index_user = []
		self.n_user = n_user
		self.n_item = n_item
		self.cv = cv
		self.lams = lams
		self.Ks = Ks
		self.iterNum = iterNum
		self.tol = tol
		self.best_model = {}
		self.cv_result = {'K': [], 'lam': [], 'train_rmse': [], 'valid_rmse': []}

	def grid_search(self, train_pair, train_rating):
		## generate all comb of `K` and `lam`
		kf = KFold(n_splits=self.cv, shuffle=True)
		for (K,lam) in itertools.product(self.Ks, self.lams):
			train_rmse_tmp, valid_rmse_tmp = 0., 0.
			for train_index, valid_index in kf.split(train_pair):
				# produce training/validation sets
				train_pair_cv, train_rating_cv = train_pair[train_index], train_rating[train_index]
				valid_pair_cv, valid_rating_cv = train_pair[valid_index], train_rating[valid_index]
				# fit the model based on CV data
				model_tmp = LFM(self.n_user, self.n_item, K=K, lam=lam, verbose=0)
				model_tmp.fit(train_pair=train_pair_cv, train_rating=train_rating_cv)
				train_rmse_tmp_cv = model_tmp.rmse(test_pair=train_pair_cv, test_rating=train_rating_cv)
				valid_rmse_tmp_cv = model_tmp.rmse(test_pair=valid_pair_cv, test_rating=valid_rating_cv)
				train_rmse_tmp = train_rmse_tmp + train_rmse_tmp_cv / self.cv
				valid_rmse_tmp = valid_rmse_tmp + valid_rmse_tmp_cv / self.cv
				print('%d-Fold CV for K: %d; lam: %.5f: train_rmse: %.3f, valid_rmse: %.3f' 
						%(self.cv, K, lam, train_rmse_tmp_cv, valid_rmse_tmp_cv))
			self.cv_result['K'].append(K)
			self.cv_result['lam'].append(lam)
			self.cv_result['train_rmse'].append(train_rmse_tmp)
			self.cv_result['valid_rmse'].append(valid_rmse_tmp)
		self.cv_result = pd.DataFrame.from_dict(self.cv_result)
		best_ind = self.cv_result['valid_rmse'].argmin()
		self.best_model = self.cv_result.loc[best_ind]
	
	def plot_grid(self, data_source='valid'):
		sns.set_theme()
		if data_source == 'train':
			cv_pivot = self.cv_result.pivot("K", "lam", "train_rmse")
		elif data_source == 'valid':
			cv_pivot = self.cv_result.pivot("K", "lam", "valid_rmse")
		else:
			raise ValueError('data_source must be train or valid!')
		sns.heatmap(cv_pivot, annot=True, fmt=".3f", linewidths=.5, cmap="YlGnBu")
		plt.show()

# %% [markdown]
# ## Process the data

# %%
dtrain = pd.read_csv('data/train.csv', 
			usecols=['user_id', 'item_id', 'rating'])
dtest = pd.read_csv('data/test.csv', usecols=['user_id', 'item_id'])
sub = pd.read_csv('predict/sample_submission.csv')

## convert string to user_id and item_id -> [user_id, item_id, rating]
# pre-process for training data
train_pair = dtrain[['user_id', 'item_id']].values
train_rating = dtrain['rating'].values
# pre-process for testing set
test_pair = dtest[['user_id', 'item_id']].values
temp_test_pair = dtest[['user_id', 'item_id']].values

user_temp=np.append(test_pair[:,0],train_pair[:,0])
item_temp=np.append(test_pair[:,1],train_pair[:,1])

test_pair[:,0]=get_id(test_pair[:,0],user_temp)
test_pair[:,1]=get_id(test_pair[:,1],item_temp)
train_pair[:,0]=get_id(train_pair[:,0],user_temp)
train_pair[:,1]=get_id(train_pair[:,1],item_temp)

n_user, n_item = max(train_pair[:,0].max(), test_pair[:,0].max())+1, max(train_pair[:,1].max(), test_pair[:,1].max())+1

# %%
dtrain = pd.read_csv("data/train.csv")
dtest = pd.read_csv("data/test.csv")

## mapping 
from sklearn import preprocessing
le_user = preprocessing.LabelEncoder()
le_user.fit(np.append(dtrain['user_id'], dtest["user_id"]))
dtrain['user_id'] = le_user.transform(dtrain["user_id"])
dtest["user_id"] = le_user.transform(dtest["user_id"])

le_item = preprocessing.LabelEncoder()
le_item.fit(np.append(dtrain['item_id'], dtest["item_id"]))
dtrain["item_id"] = le_item.transform(dtrain["item_id"])
dtest["item_id"] = le_item.transform(dtest["item_id"])

# train_pair, train_rating
train_pair = dtrain[['user_id', 'item_id']].values
train_rating = dtrain['rating'].values

# test_pair
test_pair = dtest[['user_id', 'item_id']].values
n_user, n_item = max(train_pair[:,0].max(), test_pair[:,0].max())+1, max(train_pair[:,1].max(), test_pair[:,1].max())+1

# %%
train_pair
# Out:
# array([[287, 286],
#        [287, 813],
#        [94, 676],
#        ...,
#        [2, 628],
#        [120, 954],
#        [268, 196]], dtype=object)

# %% [markdown]
# ## Exploratory data analysis (EDA)
# - User rating of the items

# %%
sns.set_theme()
## histograms of rating 
plt.figure(1, figsize=(17, 7))
sns.histplot(data=dtrain, x="rating")
plt.show()

# %%
## histograms of user 
plt.figure(1, figsize=(17, 7))
sns.histplot(data=dtrain, x="user_id")
plt.show()
## histograms of item 
plt.figure(1, figsize=(17, 7))
sns.histplot(data=dtrain, x="item_id")
plt.show()

# %%
# histgrams for averaged ratings for users/items
plt.figure(1, figsize=(17, 7))
sns.histplot(dtrain.groupby('user_id')['rating'].mean())
plt.show()
plt.figure(1, figsize=(17, 7))
sns.histplot(dtrain.groupby('item_id')['rating'].mean())
plt.show()

# %%
## Find Top-20 highest rating items
pd.DataFrame(dtrain.groupby('item_id')['rating'].mean().sort_values(ascending = False)[:20], columns =['rating'])
# Out:
#             rating
# item_id
# 6CC285   15.000000
# 12B649   15.000000
# 984286   15.000000
# A34883   15.000000
# 46615F   15.000000
# 00A6C3   14.000000
# 1F195C   14.000000
# 854152   13.000000
# 1BD1BC   13.000000
# 96E885   12.000000
# FC2A32   12.000000
# F9B8E0   12.000000
# C33FEA   12.000000
# 12CB31   12.000000
# 5460D4   12.000000
# A7F9FC   12.000000
# B03680   11.875000
# CDE71B   11.571429
# 51FEB6   11.200000
# A7B592   11.000000

# %%
## Find Top-20 most popular items 
dtmp = dtrain.groupby('item_id')['rating'].count().sort_values(ascending = False)[:20]
df=pd.DataFrame(dtrain.groupby('item_id')['rating'].count().sort_values(ascending = False)[:20])
df.columns =['Count']
print(df)
plt.figure(1, figsize=(17, 7))
sns.barplot(x=df.index, y=dtmp, order=dtmp.index)
plt.show()
# Out:
#          Count
# item_id
# 48A3FB      46
# C29496      45
# 248973      43
# FEAECC      43
# 43688C      42
# 78FEAC      42
# 5DC14E      41
# 954956      40
# 4662D7      40
# 9BD8B5      40
# AFA01C      39
# B02D4E      38
# 52B3D7      38
# 1FA901      38
# 1D2EF8      38
# 1A8CEA      38
# 9D6BE2      38
# EAB8BB      38
# 93F0A2      38
# 7DBBE3      38

# %% [markdown]
# ## Use the developed methods to predict ratings

# %% [markdown]
# GLB_LFM

# %%
## GLB_mean
glb_ave = glb_mean()
glb_ave.fit(train_rating)
pred_glb = glb_ave.predict(test_pair)
train_rating_cm = train_rating - glb_ave.predict(train_pair)

## fit GLB_mean + LFM_CV by residual ratings 
Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_cm)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair, train_rating_cm)
pred = pred_glb + shiing.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 1.098, valid_rmse: 3.715
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.863, valid_rmse: 1.535
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.873, valid_rmse: 1.518
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.958, valid_rmse: 1.822
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.876, valid_rmse: 1.506
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.119, valid_rmse: 1.608
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.109, valid_rmse: 1.601
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.109, valid_rmse: 1.595
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.102, valid_rmse: 1.562
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.113, valid_rmse: 1.572
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.424, valid_rmse: 1.778
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.411, valid_rmse: 1.839
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.431, valid_rmse: 1.772
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.419, valid_rmse: 1.835
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.429, valid_rmse: 1.744
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 3.079, valid_rmse: 3.138
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 3.110, valid_rmse: 3.011
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 3.087, valid_rmse: 3.106
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 3.069, valid_rmse: 3.175
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 3.108, valid_rmse: 3.021
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.692, valid_rmse: 1.684
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.723, valid_rmse: 1.811
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.725, valid_rmse: 2.047
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.762, valid_rmse: 2.061
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.721, valid_rmse: 1.789
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.013, valid_rmse: 1.596
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.017, valid_rmse: 1.661
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.001, valid_rmse: 1.617
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.006, valid_rmse: 1.599
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.000, valid_rmse: 1.587
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.390, valid_rmse: 1.796
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.402, valid_rmse: 1.763
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.406, valid_rmse: 1.836
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.394, valid_rmse: 1.805
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.397, valid_rmse: 1.820
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 3.077, valid_rmse: 3.146
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 3.096, valid_rmse: 3.070
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 3.083, valid_rmse: 3.122
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 3.094, valid_rmse: 3.078
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 3.104, valid_rmse: 3.037
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.407, valid_rmse: 2.105
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.407, valid_rmse: 2.102
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.418, valid_rmse: 2.088
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.403, valid_rmse: 1.976
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.399, valid_rmse: 2.022
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.884, valid_rmse: 1.613
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.879, valid_rmse: 1.672
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.882, valid_rmse: 1.623
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.886, valid_rmse: 1.665
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.880, valid_rmse: 1.688
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.368, valid_rmse: 1.870
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.373, valid_rmse: 1.803
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.384, valid_rmse: 1.781
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.373, valid_rmse: 1.821
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.377, valid_rmse: 1.824
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 3.062, valid_rmse: 3.202
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 3.093, valid_rmse: 3.082
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 3.111, valid_rmse: 3.010
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 3.108, valid_rmse: 3.020
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 3.080, valid_rmse: 3.135
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.270, valid_rmse: 2.107
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.280, valid_rmse: 2.267
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.286, valid_rmse: 2.344
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.276, valid_rmse: 2.261
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.275, valid_rmse: 2.069
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.844, valid_rmse: 1.681
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.835, valid_rmse: 1.631
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.842, valid_rmse: 1.641
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.833, valid_rmse: 1.689
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.837, valid_rmse: 1.677
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.361, valid_rmse: 1.802
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.367, valid_rmse: 1.869
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.372, valid_rmse: 1.795
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.370, valid_rmse: 1.812
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.364, valid_rmse: 1.795
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 3.091, valid_rmse: 3.090
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 3.100, valid_rmse: 3.054
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 3.083, valid_rmse: 3.122
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 3.079, valid_rmse: 3.136
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 3.100, valid_rmse: 3.051
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.223, valid_rmse: 2.103
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.224, valid_rmse: 2.098
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.228, valid_rmse: 2.088
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.227, valid_rmse: 2.225
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.229, valid_rmse: 2.219
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.814, valid_rmse: 1.690
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.817, valid_rmse: 1.677
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.819, valid_rmse: 1.593
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.819, valid_rmse: 1.688
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.816, valid_rmse: 1.725
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.365, valid_rmse: 1.859
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.366, valid_rmse: 1.818
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.361, valid_rmse: 1.782
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.363, valid_rmse: 1.759
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.364, valid_rmse: 1.900
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 3.097, valid_rmse: 3.066
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 3.093, valid_rmse: 3.080
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 3.069, valid_rmse: 3.177
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 3.108, valid_rmse: 3.019
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 3.086, valid_rmse: 3.110
# Fitting Reg-LFM: K: 3, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.266 RMSE: 2.602
# Reg-LFM: ite: 1; diff: 0.285 RMSE: 1.860
# Reg-LFM: ite: 2; diff: 0.242 RMSE: 1.410
# Reg-LFM: ite: 3; diff: 0.145 RMSE: 1.205
# Reg-LFM: ite: 4; diff: 0.022 RMSE: 1.179
# Reg-LFM: ite: 5; diff: 0.008 RMSE: 1.170
# Reg-LFM: ite: 6; diff: 0.005 RMSE: 1.164
# Reg-LFM: ite: 7; diff: 0.003 RMSE: 1.161
# Reg-LFM: ite: 8; diff: 0.002 RMSE: 1.158
# Reg-LFM: ite: 9; diff: 0.002 RMSE: 1.155

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/GLB_LFM.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 4.830147075173101
#   item   rating
# 4BC7F1 5.710617
# E36CD5 5.423305
# 604A4B 4.830147
# A98D40 3.853656
# F89A64 3.442442

# %% [markdown]
# GLB_user_mean_LMF

# %%
# user_mean
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
pred_user_mean = pred_glb + user_ave.predict(test_pair)

# fit GLB + user_mean + LFM_CV by residual ratings 
train_rating_res = train_rating_cm - user_ave.predict(train_pair)
Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.810, valid_rmse: 1.391
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.808, valid_rmse: 1.388
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.805, valid_rmse: 1.347
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.798, valid_rmse: 1.417
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.809, valid_rmse: 1.378
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.970, valid_rmse: 1.301
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.986, valid_rmse: 1.281
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.979, valid_rmse: 1.285
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.978, valid_rmse: 1.271
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.978, valid_rmse: 1.255
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.219, valid_rmse: 1.383
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.230, valid_rmse: 1.345
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.219, valid_rmse: 1.370
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.238, valid_rmse: 1.373
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.221, valid_rmse: 1.391
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.878, valid_rmse: 1.897
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.892, valid_rmse: 1.841
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.892, valid_rmse: 1.840
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.863, valid_rmse: 1.956
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.884, valid_rmse: 1.872
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.632, valid_rmse: 1.471
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.632, valid_rmse: 1.538
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.629, valid_rmse: 1.442
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.616, valid_rmse: 1.496
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.614, valid_rmse: 1.495
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.875, valid_rmse: 1.319
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.886, valid_rmse: 1.250
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.884, valid_rmse: 1.311
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.889, valid_rmse: 1.296
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.891, valid_rmse: 1.218
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.212, valid_rmse: 1.350
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.201, valid_rmse: 1.355
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.210, valid_rmse: 1.356
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.212, valid_rmse: 1.401
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.201, valid_rmse: 1.375
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.866, valid_rmse: 1.941
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.887, valid_rmse: 1.859
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.881, valid_rmse: 1.883
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.880, valid_rmse: 1.887
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.893, valid_rmse: 1.837
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.340, valid_rmse: 1.516
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.346, valid_rmse: 1.509
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.346, valid_rmse: 1.575
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.344, valid_rmse: 1.489
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.348, valid_rmse: 1.577
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.780, valid_rmse: 1.218
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.783, valid_rmse: 1.257
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.788, valid_rmse: 1.281
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.777, valid_rmse: 1.297
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.784, valid_rmse: 1.245
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.193, valid_rmse: 1.383
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.193, valid_rmse: 1.360
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.192, valid_rmse: 1.374
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.198, valid_rmse: 1.369
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.197, valid_rmse: 1.359
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.883, valid_rmse: 1.878
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.877, valid_rmse: 1.900
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.884, valid_rmse: 1.874
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.885, valid_rmse: 1.869
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.880, valid_rmse: 1.887
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.240, valid_rmse: 1.489
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.236, valid_rmse: 1.475
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.241, valid_rmse: 1.420
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.238, valid_rmse: 1.435
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.241, valid_rmse: 1.513
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.751, valid_rmse: 1.223
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.750, valid_rmse: 1.296
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.745, valid_rmse: 1.243
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.750, valid_rmse: 1.233
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.749, valid_rmse: 1.243
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.194, valid_rmse: 1.317
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.194, valid_rmse: 1.347
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.191, valid_rmse: 1.377
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.189, valid_rmse: 1.396
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.194, valid_rmse: 1.399
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.876, valid_rmse: 1.903
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.882, valid_rmse: 1.879
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.878, valid_rmse: 1.897
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.882, valid_rmse: 1.880
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.890, valid_rmse: 1.849
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.203, valid_rmse: 1.369
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.204, valid_rmse: 1.377
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.204, valid_rmse: 1.414
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.204, valid_rmse: 1.410
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.203, valid_rmse: 1.389
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.737, valid_rmse: 1.249
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.735, valid_rmse: 1.274
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.738, valid_rmse: 1.239
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.739, valid_rmse: 1.212
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.735, valid_rmse: 1.278
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.191, valid_rmse: 1.391
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.199, valid_rmse: 1.329
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.193, valid_rmse: 1.388
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.191, valid_rmse: 1.370
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.185, valid_rmse: 1.357
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.884, valid_rmse: 1.874
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.884, valid_rmse: 1.873
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.888, valid_rmse: 1.857
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.873, valid_rmse: 1.915
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.880, valid_rmse: 1.889
# Fitting Reg-LFM: K: 15, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.701 RMSE: 1.284
# Reg-LFM: ite: 1; diff: 0.292 RMSE: 0.909
# Reg-LFM: ite: 2; diff: 0.048 RMSE: 0.865
# Reg-LFM: ite: 3; diff: 0.028 RMSE: 0.841
# Reg-LFM: ite: 4; diff: 0.018 RMSE: 0.826
# Reg-LFM: ite: 5; diff: 0.012 RMSE: 0.816
# Reg-LFM: ite: 6; diff: 0.008 RMSE: 0.809
# Reg-LFM: ite: 7; diff: 0.006 RMSE: 0.804
# Reg-LFM: ite: 8; diff: 0.004 RMSE: 0.801
# Reg-LFM: ite: 9; diff: 0.003 RMSE: 0.798

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/GLB_user_mean_LFM.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 5.233236337113196
#   item   rating
# 4BC7F1 6.623828
# E36CD5 6.325177
# 604A4B 5.233236
# F89A64 2.672779
# A98D40 2.168624

# %% [markdown]
# GLB_item_mean_LMF

# %%
## item mean
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
pred_item_mean = pred_glb + item_ave.predict(test_pair)

# fit GLB + item_mean + LFM_CV by residual ratings 
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.929, valid_rmse: 1.660
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.908, valid_rmse: 1.619
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.917, valid_rmse: 1.692
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.996, valid_rmse: 2.272
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.928, valid_rmse: 1.707
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.113, valid_rmse: 1.557
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.107, valid_rmse: 1.587
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.102, valid_rmse: 1.591
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.109, valid_rmse: 1.606
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.094, valid_rmse: 1.499
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.349, valid_rmse: 1.649
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.343, valid_rmse: 1.647
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.340, valid_rmse: 1.670
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.337, valid_rmse: 1.661
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.349, valid_rmse: 1.658
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 2.652, valid_rmse: 2.609
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 2.635, valid_rmse: 2.680
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 2.637, valid_rmse: 2.671
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 2.643, valid_rmse: 2.647
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 2.652, valid_rmse: 2.611
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.715, valid_rmse: 1.825
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.738, valid_rmse: 2.027
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.728, valid_rmse: 1.910
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.731, valid_rmse: 1.873
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.704, valid_rmse: 1.766
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.997, valid_rmse: 1.606
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.980, valid_rmse: 1.511
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.979, valid_rmse: 1.592
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.973, valid_rmse: 1.515
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.002, valid_rmse: 1.525
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.301, valid_rmse: 1.686
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.311, valid_rmse: 1.606
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.307, valid_rmse: 1.661
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.327, valid_rmse: 1.692
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.325, valid_rmse: 1.644
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 2.648, valid_rmse: 2.625
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 2.641, valid_rmse: 2.655
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 2.645, valid_rmse: 2.637
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 2.629, valid_rmse: 2.701
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 2.655, valid_rmse: 2.600
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.404, valid_rmse: 2.042
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.402, valid_rmse: 1.970
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.387, valid_rmse: 1.844
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.407, valid_rmse: 2.139
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.397, valid_rmse: 2.127
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.856, valid_rmse: 1.617
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.856, valid_rmse: 1.542
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.853, valid_rmse: 1.495
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.862, valid_rmse: 1.563
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.852, valid_rmse: 1.522
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.286, valid_rmse: 1.687
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.290, valid_rmse: 1.658
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.281, valid_rmse: 1.667
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.290, valid_rmse: 1.627
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.297, valid_rmse: 1.609
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 2.616, valid_rmse: 2.753
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 2.650, valid_rmse: 2.620
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 2.640, valid_rmse: 2.657
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 2.638, valid_rmse: 2.665
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 2.674, valid_rmse: 2.517
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.262, valid_rmse: 2.050
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.265, valid_rmse: 2.089
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.264, valid_rmse: 2.004
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.266, valid_rmse: 2.028
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.259, valid_rmse: 1.963
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.804, valid_rmse: 1.594
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.808, valid_rmse: 1.532
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.806, valid_rmse: 1.574
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.806, valid_rmse: 1.623
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.809, valid_rmse: 1.534
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.287, valid_rmse: 1.627
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.281, valid_rmse: 1.672
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.284, valid_rmse: 1.634
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.276, valid_rmse: 1.670
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.280, valid_rmse: 1.637
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 2.640, valid_rmse: 2.660
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 2.643, valid_rmse: 2.645
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 2.638, valid_rmse: 2.667
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 2.651, valid_rmse: 2.615
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 2.647, valid_rmse: 2.630
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.218, valid_rmse: 1.984
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.215, valid_rmse: 1.895
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.215, valid_rmse: 1.892
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.218, valid_rmse: 1.846
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.217, valid_rmse: 1.989
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.783, valid_rmse: 1.613
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.782, valid_rmse: 1.554
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.783, valid_rmse: 1.570
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.790, valid_rmse: 1.576
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.785, valid_rmse: 1.494
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.289, valid_rmse: 1.694
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.283, valid_rmse: 1.617
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.277, valid_rmse: 1.680
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.277, valid_rmse: 1.643
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.281, valid_rmse: 1.724
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 2.650, valid_rmse: 2.617
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 2.659, valid_rmse: 2.583
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 2.633, valid_rmse: 2.688
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 2.649, valid_rmse: 2.623
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 2.628, valid_rmse: 2.706
# Fitting Reg-LFM: K: 10, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.612 RMSE: 1.574
# Reg-LFM: ite: 1; diff: 0.315 RMSE: 1.078
# Reg-LFM: ite: 2; diff: 0.057 RMSE: 1.017
# Reg-LFM: ite: 3; diff: 0.034 RMSE: 0.982
# Reg-LFM: ite: 4; diff: 0.024 RMSE: 0.959
# Reg-LFM: ite: 5; diff: 0.017 RMSE: 0.943
# Reg-LFM: ite: 6; diff: 0.013 RMSE: 0.931
# Reg-LFM: ite: 7; diff: 0.010 RMSE: 0.922
# Reg-LFM: ite: 8; diff: 0.008 RMSE: 0.915
# Reg-LFM: ite: 9; diff: 0.006 RMSE: 0.909

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/GLB_item_mean_LFM.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 4.070218075329894
#   item   rating
# 90EC84 5.325922
# E36CD5 4.717599
# 604A4B 4.070218
# A98D40 1.810112
# F89A64 1.551450

# %% [markdown]
# user_item_mean_LMF

# %%
## user_mean + item mean + LFM
## user_mean 
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred = user_ave.predict(test_pair)

## item_mean
train_rating_cm = train_rating - user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred = pred + item_ave.predict(test_pair)



## fit user_mean + item_mean + LFM_CV by residual ratings 
Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.791, valid_rmse: 1.375
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.805, valid_rmse: 1.356
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.806, valid_rmse: 1.288
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.796, valid_rmse: 1.300
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.800, valid_rmse: 1.287
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.924, valid_rmse: 1.116
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.919, valid_rmse: 1.128
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.919, valid_rmse: 1.141
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.922, valid_rmse: 1.080
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.934, valid_rmse: 1.137
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.100, valid_rmse: 1.135
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.095, valid_rmse: 1.131
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.104, valid_rmse: 1.162
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.100, valid_rmse: 1.142
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.102, valid_rmse: 1.143
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.159, valid_rmse: 1.183
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.163, valid_rmse: 1.168
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.168, valid_rmse: 1.145
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.166, valid_rmse: 1.153
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.162, valid_rmse: 1.169
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.619, valid_rmse: 1.338
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.610, valid_rmse: 1.376
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.622, valid_rmse: 1.363
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.623, valid_rmse: 1.349
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.621, valid_rmse: 1.405
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.837, valid_rmse: 1.083
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.835, valid_rmse: 1.097
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.847, valid_rmse: 1.102
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.843, valid_rmse: 1.102
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.837, valid_rmse: 1.102
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.090, valid_rmse: 1.169
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.092, valid_rmse: 1.136
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.091, valid_rmse: 1.137
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.092, valid_rmse: 1.124
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.087, valid_rmse: 1.133
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.157, valid_rmse: 1.191
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.166, valid_rmse: 1.154
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.166, valid_rmse: 1.153
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.163, valid_rmse: 1.168
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.167, valid_rmse: 1.152
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.353, valid_rmse: 1.388
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.353, valid_rmse: 1.397
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.355, valid_rmse: 1.414
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.346, valid_rmse: 1.385
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.347, valid_rmse: 1.333
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.743, valid_rmse: 1.048
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.747, valid_rmse: 1.041
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.740, valid_rmse: 1.091
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.751, valid_rmse: 1.035
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.740, valid_rmse: 1.062
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.080, valid_rmse: 1.129
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.081, valid_rmse: 1.122
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.083, valid_rmse: 1.132
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.082, valid_rmse: 1.153
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.084, valid_rmse: 1.151
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.160, valid_rmse: 1.177
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.160, valid_rmse: 1.177
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.168, valid_rmse: 1.145
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.161, valid_rmse: 1.175
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.169, valid_rmse: 1.144
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.242, valid_rmse: 1.296
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.240, valid_rmse: 1.229
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.240, valid_rmse: 1.266
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.240, valid_rmse: 1.217
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.243, valid_rmse: 1.226
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.717, valid_rmse: 1.032
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.715, valid_rmse: 1.051
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.717, valid_rmse: 1.042
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.717, valid_rmse: 1.061
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.717, valid_rmse: 1.048
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.083, valid_rmse: 1.127
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.084, valid_rmse: 1.100
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.077, valid_rmse: 1.151
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.084, valid_rmse: 1.139
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.079, valid_rmse: 1.166
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.167, valid_rmse: 1.152
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.157, valid_rmse: 1.192
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.165, valid_rmse: 1.157
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.165, valid_rmse: 1.157
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.165, valid_rmse: 1.161
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.204, valid_rmse: 1.177
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.205, valid_rmse: 1.182
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.205, valid_rmse: 1.160
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.204, valid_rmse: 1.145
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.206, valid_rmse: 1.156
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.707, valid_rmse: 1.063
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.707, valid_rmse: 1.026
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.707, valid_rmse: 1.043
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.709, valid_rmse: 1.060
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.708, valid_rmse: 1.053
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.082, valid_rmse: 1.142
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.081, valid_rmse: 1.144
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.078, valid_rmse: 1.136
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.078, valid_rmse: 1.142
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.080, valid_rmse: 1.121
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.160, valid_rmse: 1.178
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.162, valid_rmse: 1.169
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.164, valid_rmse: 1.163
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.167, valid_rmse: 1.152
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.165, valid_rmse: 1.157
# Fitting Reg-LFM: K: 15, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.757 RMSE: 0.999
# Reg-LFM: ite: 1; diff: 0.099 RMSE: 0.900
# Reg-LFM: ite: 2; diff: 0.073 RMSE: 0.835
# Reg-LFM: ite: 3; diff: 0.038 RMSE: 0.803
# Reg-LFM: ite: 4; diff: 0.021 RMSE: 0.786
# Reg-LFM: ite: 5; diff: 0.013 RMSE: 0.776
# Reg-LFM: ite: 6; diff: 0.008 RMSE: 0.770
# Reg-LFM: ite: 7; diff: 0.005 RMSE: 0.766
# Reg-LFM: ite: 8; diff: 0.004 RMSE: 0.763
# Reg-LFM: ite: 9; diff: 0.002 RMSE: 0.761

# %%
## user_mean + item mean + LFM
## user_mean 
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred = user_ave.predict(test_pair)

## item_mean
train_rating_cm = train_rating - user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred = pred + item_ave.predict(test_pair)



## fit user_mean + item_mean + LFM_CV by residual ratings 
Ks, lams = [15,16,17,18,19,20],[0.0003,0.00035,0.0004]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam,iterNum=30)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
## print T-th record and top-5 preferred items
print_T(0,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)
# Out:
# 5-Fold CV for K: 15; lam: 0.00030: train_rmse: 0.507, valid_rmse: 1.053
# 5-Fold CV for K: 15; lam: 0.00030: train_rmse: 0.509, valid_rmse: 1.063
# 5-Fold CV for K: 15; lam: 0.00030: train_rmse: 0.506, valid_rmse: 1.048
# 5-Fold CV for K: 15; lam: 0.00030: train_rmse: 0.507, valid_rmse: 1.051
# 5-Fold CV for K: 15; lam: 0.00030: train_rmse: 0.508, valid_rmse: 1.050
# 5-Fold CV for K: 15; lam: 0.00035: train_rmse: 0.565, valid_rmse: 1.049
# 5-Fold CV for K: 15; lam: 0.00035: train_rmse: 0.565, valid_rmse: 1.043
# 5-Fold CV for K: 15; lam: 0.00035: train_rmse: 0.560, valid_rmse: 1.063
# 5-Fold CV for K: 15; lam: 0.00035: train_rmse: 0.561, valid_rmse: 1.059
# 5-Fold CV for K: 15; lam: 0.00035: train_rmse: 0.564, valid_rmse: 1.011
# 5-Fold CV for K: 15; lam: 0.00040: train_rmse: 0.614, valid_rmse: 1.011
# 5-Fold CV for K: 15; lam: 0.00040: train_rmse: 0.618, valid_rmse: 1.040
# 5-Fold CV for K: 15; lam: 0.00040: train_rmse: 0.617, valid_rmse: 1.030
# 5-Fold CV for K: 15; lam: 0.00040: train_rmse: 0.613, valid_rmse: 1.062
# 5-Fold CV for K: 15; lam: 0.00040: train_rmse: 0.621, valid_rmse: 1.048
# 5-Fold CV for K: 16; lam: 0.00030: train_rmse: 0.499, valid_rmse: 1.021
# 5-Fold CV for K: 16; lam: 0.00030: train_rmse: 0.500, valid_rmse: 1.062
# 5-Fold CV for K: 16; lam: 0.00030: train_rmse: 0.498, valid_rmse: 1.010
# 5-Fold CV for K: 16; lam: 0.00030: train_rmse: 0.499, valid_rmse: 1.073
# 5-Fold CV for K: 16; lam: 0.00030: train_rmse: 0.502, valid_rmse: 1.019
# 5-Fold CV for K: 16; lam: 0.00035: train_rmse: 0.557, valid_rmse: 1.026
# 5-Fold CV for K: 16; lam: 0.00035: train_rmse: 0.556, valid_rmse: 1.026
# 5-Fold CV for K: 16; lam: 0.00035: train_rmse: 0.556, valid_rmse: 1.045
# 5-Fold CV for K: 16; lam: 0.00035: train_rmse: 0.557, valid_rmse: 1.024
# 5-Fold CV for K: 16; lam: 0.00035: train_rmse: 0.558, valid_rmse: 1.059
# 5-Fold CV for K: 16; lam: 0.00040: train_rmse: 0.611, valid_rmse: 1.033
# 5-Fold CV for K: 16; lam: 0.00040: train_rmse: 0.612, valid_rmse: 1.019
# 5-Fold CV for K: 16; lam: 0.00040: train_rmse: 0.611, valid_rmse: 1.039
# 5-Fold CV for K: 16; lam: 0.00040: train_rmse: 0.614, valid_rmse: 1.054
# 5-Fold CV for K: 16; lam: 0.00040: train_rmse: 0.610, valid_rmse: 1.048
# 5-Fold CV for K: 17; lam: 0.00030: train_rmse: 0.493, valid_rmse: 1.047
# 5-Fold CV for K: 17; lam: 0.00030: train_rmse: 0.495, valid_rmse: 1.018
# 5-Fold CV for K: 17; lam: 0.00030: train_rmse: 0.493, valid_rmse: 1.025
# 5-Fold CV for K: 17; lam: 0.00030: train_rmse: 0.493, valid_rmse: 1.041
# 5-Fold CV for K: 17; lam: 0.00030: train_rmse: 0.496, valid_rmse: 1.059
# 5-Fold CV for K: 17; lam: 0.00035: train_rmse: 0.552, valid_rmse: 1.046
# 5-Fold CV for K: 17; lam: 0.00035: train_rmse: 0.555, valid_rmse: 1.028
# 5-Fold CV for K: 17; lam: 0.00035: train_rmse: 0.553, valid_rmse: 1.003
# 5-Fold CV for K: 17; lam: 0.00035: train_rmse: 0.554, valid_rmse: 1.025
# 5-Fold CV for K: 17; lam: 0.00035: train_rmse: 0.553, valid_rmse: 1.046
# 5-Fold CV for K: 17; lam: 0.00040: train_rmse: 0.609, valid_rmse: 1.040
# 5-Fold CV for K: 17; lam: 0.00040: train_rmse: 0.609, valid_rmse: 1.023
# 5-Fold CV for K: 17; lam: 0.00040: train_rmse: 0.608, valid_rmse: 1.043
# 5-Fold CV for K: 17; lam: 0.00040: train_rmse: 0.614, valid_rmse: 1.038
# 5-Fold CV for K: 17; lam: 0.00040: train_rmse: 0.610, valid_rmse: 1.046
# 5-Fold CV for K: 18; lam: 0.00030: train_rmse: 0.490, valid_rmse: 1.057
# 5-Fold CV for K: 18; lam: 0.00030: train_rmse: 0.489, valid_rmse: 1.018
# 5-Fold CV for K: 18; lam: 0.00030: train_rmse: 0.491, valid_rmse: 1.043
# 5-Fold CV for K: 18; lam: 0.00030: train_rmse: 0.495, valid_rmse: 1.034
# 5-Fold CV for K: 18; lam: 0.00030: train_rmse: 0.488, valid_rmse: 1.056
# 5-Fold CV for K: 18; lam: 0.00035: train_rmse: 0.549, valid_rmse: 1.046
# 5-Fold CV for K: 18; lam: 0.00035: train_rmse: 0.552, valid_rmse: 1.051
# 5-Fold CV for K: 18; lam: 0.00035: train_rmse: 0.548, valid_rmse: 1.031
# 5-Fold CV for K: 18; lam: 0.00035: train_rmse: 0.551, valid_rmse: 1.006
# 5-Fold CV for K: 18; lam: 0.00035: train_rmse: 0.551, valid_rmse: 1.030
# 5-Fold CV for K: 18; lam: 0.00040: train_rmse: 0.608, valid_rmse: 1.022
# 5-Fold CV for K: 18; lam: 0.00040: train_rmse: 0.606, valid_rmse: 1.035
# 5-Fold CV for K: 18; lam: 0.00040: train_rmse: 0.607, valid_rmse: 1.046
# 5-Fold CV for K: 18; lam: 0.00040: train_rmse: 0.604, valid_rmse: 1.033
# 5-Fold CV for K: 18; lam: 0.00040: train_rmse: 0.604, valid_rmse: 1.037
# 5-Fold CV for K: 19; lam: 0.00030: train_rmse: 0.489, valid_rmse: 1.027
# 5-Fold CV for K: 19; lam: 0.00030: train_rmse: 0.485, valid_rmse: 1.025
# 5-Fold CV for K: 19; lam: 0.00030: train_rmse: 0.489, valid_rmse: 1.058
# 5-Fold CV for K: 19; lam: 0.00030: train_rmse: 0.489, valid_rmse: 1.049
# 5-Fold CV for K: 19; lam: 0.00030: train_rmse: 0.485, valid_rmse: 1.044
# 5-Fold CV for K: 19; lam: 0.00035: train_rmse: 0.547, valid_rmse: 1.028
# 5-Fold CV for K: 19; lam: 0.00035: train_rmse: 0.546, valid_rmse: 1.020
# 5-Fold CV for K: 19; lam: 0.00035: train_rmse: 0.545, valid_rmse: 1.061
# 5-Fold CV for K: 19; lam: 0.00035: train_rmse: 0.549, valid_rmse: 1.017
# 5-Fold CV for K: 19; lam: 0.00035: train_rmse: 0.547, valid_rmse: 1.046
# 5-Fold CV for K: 19; lam: 0.00040: train_rmse: 0.604, valid_rmse: 1.056
# 5-Fold CV for K: 19; lam: 0.00040: train_rmse: 0.601, valid_rmse: 1.046
# 5-Fold CV for K: 19; lam: 0.00040: train_rmse: 0.605, valid_rmse: 1.016
# 5-Fold CV for K: 19; lam: 0.00040: train_rmse: 0.605, valid_rmse: 1.035
# 5-Fold CV for K: 19; lam: 0.00040: train_rmse: 0.604, valid_rmse: 1.019
# 5-Fold CV for K: 20; lam: 0.00030: train_rmse: 0.484, valid_rmse: 1.056
# 5-Fold CV for K: 20; lam: 0.00030: train_rmse: 0.484, valid_rmse: 1.039
# 5-Fold CV for K: 20; lam: 0.00030: train_rmse: 0.485, valid_rmse: 1.024
# 5-Fold CV for K: 20; lam: 0.00030: train_rmse: 0.483, valid_rmse: 1.031
# 5-Fold CV for K: 20; lam: 0.00030: train_rmse: 0.484, valid_rmse: 1.023
# 5-Fold CV for K: 20; lam: 0.00035: train_rmse: 0.544, valid_rmse: 1.029
# 5-Fold CV for K: 20; lam: 0.00035: train_rmse: 0.545, valid_rmse: 1.023
# 5-Fold CV for K: 20; lam: 0.00035: train_rmse: 0.544, valid_rmse: 1.033
# 5-Fold CV for K: 20; lam: 0.00035: train_rmse: 0.544, valid_rmse: 1.044
# 5-Fold CV for K: 20; lam: 0.00035: train_rmse: 0.546, valid_rmse: 1.031
# 5-Fold CV for K: 20; lam: 0.00040: train_rmse: 0.603, valid_rmse: 1.052
# 5-Fold CV for K: 20; lam: 0.00040: train_rmse: 0.601, valid_rmse: 1.029
# 5-Fold CV for K: 20; lam: 0.00040: train_rmse: 0.604, valid_rmse: 1.034
# 5-Fold CV for K: 20; lam: 0.00040: train_rmse: 0.600, valid_rmse: 1.017
# 5-Fold CV for K: 20; lam: 0.00040: train_rmse: 0.601, valid_rmse: 1.041
# Fitting Reg-LFM: K: 17, lam: 0.00035
# Reg-LFM: ite: 0; diff: 0.788 RMSE: 0.907
# Reg-LFM: ite: 1; diff: 0.196 RMSE: 0.729
# Reg-LFM: ite: 2; diff: 0.084 RMSE: 0.668
# Reg-LFM: ite: 3; diff: 0.044 RMSE: 0.639
# Reg-LFM: ite: 4; diff: 0.026 RMSE: 0.622
# Reg-LFM: ite: 5; diff: 0.017 RMSE: 0.612
# Reg-LFM: ite: 6; diff: 0.010 RMSE: 0.606
# Reg-LFM: ite: 7; diff: 0.007 RMSE: 0.602
# Reg-LFM: ite: 8; diff: 0.004 RMSE: 0.599
# Reg-LFM: ite: 9; diff: 0.003 RMSE: 0.597
# Reg-LFM: ite: 10; diff: 0.002 RMSE: 0.596
# Reg-LFM: ite: 11; diff: 0.002 RMSE: 0.595
# Reg-LFM: ite: 12; diff: 0.001 RMSE: 0.594
# Reg-LFM: ite: 13; diff: 0.001 RMSE: 0.594
# Reg-LFM: ite: 14; diff: 0.001 RMSE: 0.593
# Reg-LFM: ite: 15; diff: 0.001 RMSE: 0.593
# Reg-LFM: ite: 16; diff: 0.001 RMSE: 0.593
# Reg-LFM: ite: 17; diff: 0.000 RMSE: 0.592
# Reg-LFM: ite: 18; diff: 0.000 RMSE: 0.592
# Reg-LFM: ite: 19; diff: 0.000 RMSE: 0.592
# Reg-LFM: ite: 20; diff: 0.000 RMSE: 0.592
# Reg-LFM: ite: 21; diff: 0.000 RMSE: 0.592
# Reg-LFM: ite: 22; diff: 0.000 RMSE: 0.592
# Reg-LFM: ite: 23; diff: 0.000 RMSE: 0.591
# Reg-LFM: ite: 24; diff: 0.000 RMSE: 0.591
# Reg-LFM: ite: 25; diff: 0.000 RMSE: 0.591
# Reg-LFM: ite: 26; diff: 0.000 RMSE: 0.591
# Reg-LFM: ite: 27; diff: 0.000 RMSE: 0.591
# Reg-LFM: ite: 28; diff: 0.000 RMSE: 0.591
# Reg-LFM: ite: 29; diff: 0.000 RMSE: 0.591
# test_pair: ['EF01AF' 'DFA2D2']
# pred_rating: 2.111260272686128
#    item    rating
#  604A4B  6.722739
#  A98D40  5.489004
#  F89A64  5.475989
#  E36CD5  4.257328
#  4BC7F1  3.161753

# %%
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred = user_ave.predict(test_pair)

## item_mean
train_rating_cm = train_rating - user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred = pred + item_ave.predict(test_pair)


shiing=LFM(n_user, n_item, K=15, lam=0.00040,iterNum=50)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
## print T-th record and top-5 preferred items
print_T(0,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)


## RMSE=1.149
# Out:
# Fitting Reg-LFM: K: 15, lam: 0.00040
# Reg-LFM: ite: 0; diff: 0.766 RMSE: 0.949
# Reg-LFM: ite: 1; diff: 0.159 RMSE: 0.798
# Reg-LFM: ite: 2; diff: 0.078 RMSE: 0.736
# Reg-LFM: ite: 3; diff: 0.044 RMSE: 0.703
# Reg-LFM: ite: 4; diff: 0.027 RMSE: 0.684
# Reg-LFM: ite: 5; diff: 0.017 RMSE: 0.673
# Reg-LFM: ite: 6; diff: 0.010 RMSE: 0.666
# Reg-LFM: ite: 7; diff: 0.006 RMSE: 0.662
# Reg-LFM: ite: 8; diff: 0.004 RMSE: 0.659
# Reg-LFM: ite: 9; diff: 0.002 RMSE: 0.658
# Reg-LFM: ite: 10; diff: 0.002 RMSE: 0.657
# Reg-LFM: ite: 11; diff: 0.001 RMSE: 0.656
# Reg-LFM: ite: 12; diff: 0.001 RMSE: 0.655
# Reg-LFM: ite: 13; diff: 0.001 RMSE: 0.655
# Reg-LFM: ite: 14; diff: 0.001 RMSE: 0.654
# Reg-LFM: ite: 15; diff: 0.001 RMSE: 0.654
# Reg-LFM: ite: 16; diff: 0.000 RMSE: 0.654
# Reg-LFM: ite: 17; diff: 0.000 RMSE: 0.654
# Reg-LFM: ite: 18; diff: 0.000 RMSE: 0.653
# Reg-LFM: ite: 19; diff: 0.000 RMSE: 0.653
# Reg-LFM: ite: 20; diff: 0.000 RMSE: 0.653
# Reg-LFM: ite: 21; diff: 0.000 RMSE: 0.653
# Reg-LFM: ite: 22; diff: 0.000 RMSE: 0.653
# Reg-LFM: ite: 23; diff: 0.000 RMSE: 0.653
# Reg-LFM: ite: 24; diff: 0.000 RMSE: 0.653
# Reg-LFM: ite: 25; diff: 0.000 RMSE: 0.652
# Reg-LFM: ite: 26; diff: 0.000 RMSE: 0.652
# Reg-LFM: ite: 27; diff: 0.000 RMSE: 0.652
# Reg-LFM: ite: 28; diff: 0.000 RMSE: 0.652
# Reg-LFM: ite: 29; diff: 0.000 RMSE: 0.652
# Reg-LFM: ite: 30; diff: 0.000 RMSE: 0.652
# Reg-LFM: ite: 31; diff: 0.000 RMSE: 0.652
# test_pair: ['EF01AF' 'DFA2D2']
# pred_rating: 2.141054185857531
#    item    rating
#  604A4B  6.681959
#  A98D40  5.582011
#  F89A64  5.532315
#  E36CD5  4.254369
#  4BC7F1  3.134401

# %%
# submission
pred_rating = adjust(pred_rating, 0, 15)
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_LFM_15_0.0004.csv', index=False)

# %%
## user_mean + item mean + LFM
## user_mean 
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred = user_ave.predict(test_pair)

## item_mean
train_rating_cm = train_rating - user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred = pred + item_ave.predict(test_pair)
dtrain['res_rating'] = train_rating_res

# %%
from sklearn.preprocessing import StandardScaler

user_info = pd.DataFrame({'user_id': list(range(n_user))})
user_info = user_info.set_index('user_id')
user_info['mean'] = dtrain.groupby('user_id')['res_rating'].mean()
user_info['q1'] = dtrain.groupby('user_id')['res_rating'].quantile(.1)
user_info['q3'] = dtrain.groupby('user_id')['res_rating'].quantile(.3)
user_info['q5'] = dtrain.groupby('user_id')['res_rating'].quantile(.5)
user_info['q7'] = dtrain.groupby('user_id')['res_rating'].quantile(.7)
user_info['q7'] = dtrain.groupby('user_id')['res_rating'].quantile(.9)
## fill NAN as the column mean
user_info = user_info.fillna(user_info.mean())
user_scaler = StandardScaler()
user_info = user_scaler.fit_transform(user_info)


item_info = pd.DataFrame({'item_id': list(range(n_item))})
item_info = item_info.set_index('item_id')
item_info['mean'] = dtrain.groupby('item_id')['res_rating'].mean()
item_info['q1'] = dtrain.groupby('item_id')['res_rating'].quantile(.1)
item_info['q3'] = dtrain.groupby('item_id')['res_rating'].quantile(.3)
item_info['q5'] = dtrain.groupby('item_id')['res_rating'].quantile(.5)
item_info['q7'] = dtrain.groupby('item_id')['res_rating'].quantile(.7)
item_info['q7'] = dtrain.groupby('item_id')['res_rating'].quantile(.9)
## fill NAN as the column mean
item_info = item_info.fillna(item_info.mean())
item_scaler = StandardScaler()
item_info = item_scaler.fit_transform(item_info)

# %%
user_info
# Out:
# array([[-0.21002926, -0.44897003, -0.60557075,  0.07925146,  0.46150664],
#        [-0.00429153,  0.02231299, -0.08386946,  0.17809978,  0.48686177],
#        [ 0.11726747, -0.31749303, -0.18781388, -0.00412349,  0.45707553],
#        ...,
#        [-0.54833334,  0.25794991,  0.08819271, -0.6959374 , -1.22422098],
#        [-0.23806032,  0.14190889,  0.38068749, -0.02112492, -0.73086773],
#        [-0.08126426,  0.46528331,  0.24447026,  0.10722004, -0.57224061]])

# %%
from sklearn.metrics.pairwise import cosine_similarity
user_sim = cosine_similarity(user_info)
item_sim = cosine_similarity(item_info)

# %%
top = 5
index_item = [np.where(train_pair[:,1] == i)[0] for i in range(n_item)]
index_user = [np.where(train_pair[:,0] == u)[0] for u in range(n_user)]
## augmented data
fake_pair, fake_rating = [], []
for u in range(n_user):
	print('UserId: %d' %u)
	top_user_tmp = user_sim[u].argsort()[-top:][::-1]
	valid_user_ind = []
	for u_tmp in top_user_tmp:
		valid_user_ind.extend(index_user[u_tmp])
	obs_item_tmp = train_pair[valid_user_ind,1]
	for i in range(n_item):
		top_item_tmp = item_sim[i].argsort()[-top:][::-1]
		valid_item_tmp = np.intersect1d(top_item_tmp, obs_item_tmp)
		if len(valid_item_tmp) == 0:
			continue
		valid_item_ind = []
		for i_tmp in valid_item_tmp:
			valid_item_ind.extend(index_item[i_tmp])
		valid_ind = np.intersect1d(valid_user_ind, valid_item_ind)
		if len(valid_ind) > 0:
			fake_pair.append([u,i])
			fake_rating.append(train_rating_res[valid_ind].mean())
fake_pair, fake_rating = np.array(fake_pair), np.array(fake_rating)
# Out:
# UserId: 0
# UserId: 1
# UserId: 2
# UserId: 3
# UserId: 4
# UserId: 5
# UserId: 6
# UserId: 7
# UserId: 8
# UserId: 9
# UserId: 10
# UserId: 11
# UserId: 12
# UserId: 13
# UserId: 14
# UserId: 15
# UserId: 16
# UserId: 17
# UserId: 18
# UserId: 19
# UserId: 20
# UserId: 21
# UserId: 22
# UserId: 23
# UserId: 24
# UserId: 25
# UserId: 26
# UserId: 27
# UserId: 28
# UserId: 29
# UserId: 30
# UserId: 31
# UserId: 32
# UserId: 33
# UserId: 34
# UserId: 35
# UserId: 36
# UserId: 37
# UserId: 38
# UserId: 39
# UserId: 40
# UserId: 41
# UserId: 42
# UserId: 43
# UserId: 44
# UserId: 45
# UserId: 46
# UserId: 47
# UserId: 48
# UserId: 49
# UserId: 50
# UserId: 51
# UserId: 52
# UserId: 53
# UserId: 54
# UserId: 55
# UserId: 56
# UserId: 57
# UserId: 58
# UserId: 59
# UserId: 60
# UserId: 61
# UserId: 62
# UserId: 63
# UserId: 64
# UserId: 65
# UserId: 66
# UserId: 67
# UserId: 68
# UserId: 69
# UserId: 70
# UserId: 71
# UserId: 72
# UserId: 73
# UserId: 74
# UserId: 75
# UserId: 76
# UserId: 77
# UserId: 78
# UserId: 79
# UserId: 80
# UserId: 81
# UserId: 82
# UserId: 83
# UserId: 84
# UserId: 85
# UserId: 86
# UserId: 87
# UserId: 88
# UserId: 89
# UserId: 90
# UserId: 91
# UserId: 92
# UserId: 93
# UserId: 94
# UserId: 95
# UserId: 96
# UserId: 97
# UserId: 98
# UserId: 99
# UserId: 100
# UserId: 101
# UserId: 102
# UserId: 103
# UserId: 104
# UserId: 105
# UserId: 106
# UserId: 107
# UserId: 108
# UserId: 109
# UserId: 110
# UserId: 111
# UserId: 112
# UserId: 113
# UserId: 114
# UserId: 115
# UserId: 116
# UserId: 117
# UserId: 118
# UserId: 119
# UserId: 120
# UserId: 121
# UserId: 122
# UserId: 123
# UserId: 124
# UserId: 125
# UserId: 126
# UserId: 127
# UserId: 128
# UserId: 129
# UserId: 130
# UserId: 131
# UserId: 132
# UserId: 133
# UserId: 134
# UserId: 135
# UserId: 136
# UserId: 137
# UserId: 138
# UserId: 139
# UserId: 140
# UserId: 141
# UserId: 142
# UserId: 143
# UserId: 144
# UserId: 145
# UserId: 146
# UserId: 147
# UserId: 148
# UserId: 149
# UserId: 150
# UserId: 151
# UserId: 152
# UserId: 153
# UserId: 154
# UserId: 155
# UserId: 156
# UserId: 157
# UserId: 158
# UserId: 159
# UserId: 160
# UserId: 161
# UserId: 162
# UserId: 163
# UserId: 164
# UserId: 165
# UserId: 166
# UserId: 167
# UserId: 168
# UserId: 169
# UserId: 170
# UserId: 171
# UserId: 172
# UserId: 173
# UserId: 174
# UserId: 175
# UserId: 176
# UserId: 177
# UserId: 178
# UserId: 179
# UserId: 180
# UserId: 181
# UserId: 182
# UserId: 183
# UserId: 184
# UserId: 185
# UserId: 186
# UserId: 187
# UserId: 188
# UserId: 189
# UserId: 190
# UserId: 191
# UserId: 192
# UserId: 193
# UserId: 194
# UserId: 195
# UserId: 196
# UserId: 197
# UserId: 198
# UserId: 199
# UserId: 200
# UserId: 201
# UserId: 202
# UserId: 203
# UserId: 204
# UserId: 205
# UserId: 206
# UserId: 207
# UserId: 208
# UserId: 209
# UserId: 210
# UserId: 211
# UserId: 212
# UserId: 213
# UserId: 214
# UserId: 215
# UserId: 216
# UserId: 217
# UserId: 218
# UserId: 219
# UserId: 220
# UserId: 221
# UserId: 222
# UserId: 223
# UserId: 224
# UserId: 225
# UserId: 226
# UserId: 227
# UserId: 228
# UserId: 229
# UserId: 230
# UserId: 231
# UserId: 232
# UserId: 233
# UserId: 234
# UserId: 235
# UserId: 236
# UserId: 237
# UserId: 238
# UserId: 239
# UserId: 240
# UserId: 241
# UserId: 242
# UserId: 243
# UserId: 244
# UserId: 245
# UserId: 246
# UserId: 247
# UserId: 248
# UserId: 249
# UserId: 250
# UserId: 251
# UserId: 252
# UserId: 253
# UserId: 254
# UserId: 255
# UserId: 256
# UserId: 257
# UserId: 258
# UserId: 259
# UserId: 260
# UserId: 261
# UserId: 262
# UserId: 263
# UserId: 264
# UserId: 265
# UserId: 266
# UserId: 267
# UserId: 268
# UserId: 269
# UserId: 270
# UserId: 271
# UserId: 272
# UserId: 273
# UserId: 274
# UserId: 275
# UserId: 276
# UserId: 277
# UserId: 278
# UserId: 279
# UserId: 280
# UserId: 281
# UserId: 282
# UserId: 283
# UserId: 284
# UserId: 285
# UserId: 286
# UserId: 287
# UserId: 288
# UserId: 289
# UserId: 290
# UserId: 291
# UserId: 292
# UserId: 293
# UserId: 294
# UserId: 295
# UserId: 296
# UserId: 297
# UserId: 298
# UserId: 299
# UserId: 300
# UserId: 301
# UserId: 302
# UserId: 303
# UserId: 304
# UserId: 305
# UserId: 306
# UserId: 307
# UserId: 308
# UserId: 309
# UserId: 310
# UserId: 311
# UserId: 312
# UserId: 313
# UserId: 314
# UserId: 315
# UserId: 316
# UserId: 317
# UserId: 318
# UserId: 319
# UserId: 320
# UserId: 321
# UserId: 322
# UserId: 323
# UserId: 324
# UserId: 325
# UserId: 326
# UserId: 327
# UserId: 328
# UserId: 329
# UserId: 330
# UserId: 331
# UserId: 332
# UserId: 333
# UserId: 334
# UserId: 335
# UserId: 336
# UserId: 337
# UserId: 338
# UserId: 339
# UserId: 340
# UserId: 341
# UserId: 342
# UserId: 343
# UserId: 344
# UserId: 345
# UserId: 346
# UserId: 347
# UserId: 348
# UserId: 349
# UserId: 350
# UserId: 351
# UserId: 352
# UserId: 353
# UserId: 354
# UserId: 355
# UserId: 356
# UserId: 357
# UserId: 358
# UserId: 359
# UserId: 360
# UserId: 361
# UserId: 362
# UserId: 363
# UserId: 364
# UserId: 365
# UserId: 366
# UserId: 367
# UserId: 368
# UserId: 369
# UserId: 370
# UserId: 371
# UserId: 372
# UserId: 373
# UserId: 374
# UserId: 375
# UserId: 376
# UserId: 377
# UserId: 378
# UserId: 379
# UserId: 380
# UserId: 381
# UserId: 382
# UserId: 383
# UserId: 384
# UserId: 385
# UserId: 386
# UserId: 387
# UserId: 388
# UserId: 389
# UserId: 390
# UserId: 391
# UserId: 392
# UserId: 393
# UserId: 394
# UserId: 395
# UserId: 396
# UserId: 397
# UserId: 398
# UserId: 399
# UserId: 400
# UserId: 401
# UserId: 402
# UserId: 403
# UserId: 404
# UserId: 405
# UserId: 406
# UserId: 407
# UserId: 408
# UserId: 409
# UserId: 410
# UserId: 411
# UserId: 412
# UserId: 413
# UserId: 414
# UserId: 415
# UserId: 416
# UserId: 417
# UserId: 418
# UserId: 419
# UserId: 420
# UserId: 421
# UserId: 422
# UserId: 423
# UserId: 424
# UserId: 425
# UserId: 426
# UserId: 427
# UserId: 428
# UserId: 429
# UserId: 430
# UserId: 431
# UserId: 432
# UserId: 433
# UserId: 434
# UserId: 435
# UserId: 436
# UserId: 437
# UserId: 438
# UserId: 439
# UserId: 440
# UserId: 441
# UserId: 442
# UserId: 443
# UserId: 444
# UserId: 445
# UserId: 446
# UserId: 447
# UserId: 448
# UserId: 449
# UserId: 450
# UserId: 451
# UserId: 452
# UserId: 453
# UserId: 454
# UserId: 455
# UserId: 456
# UserId: 457
# UserId: 458
# UserId: 459
# UserId: 460
# UserId: 461
# UserId: 462
# UserId: 463
# UserId: 464
# UserId: 465
# UserId: 466
# UserId: 467
# UserId: 468
# UserId: 469
# UserId: 470
# UserId: 471
# UserId: 472
# UserId: 473
# UserId: 474
# UserId: 475
# UserId: 476
# UserId: 477
# UserId: 478
# UserId: 479
# UserId: 480
# UserId: 481
# UserId: 482
# UserId: 483
# UserId: 484
# UserId: 485
# UserId: 486
# UserId: 487
# UserId: 488
# UserId: 489
# UserId: 490
# UserId: 491

# %%
aug_pair, aug_rating_res = np.vstack((train_pair, fake_pair)), np.hstack((train_rating_res, fake_rating))

Ks, lams = [20],[0.0001,0.00005,0.00001,0.000005,0.000001]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(aug_pair, aug_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']

sSVD=LFM(n_user, n_item, K=best_K, lam=best_lam)
sSVD.fit(aug_pair, aug_rating_res)
pred = pred + sSVD.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.722, valid_rmse: 0.804
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.720, valid_rmse: 0.808
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.721, valid_rmse: 0.807
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.719, valid_rmse: 0.808
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.723, valid_rmse: 0.806
# 5-Fold CV for K: 20; lam: 0.00005: train_rmse: 0.674, valid_rmse: 0.785
# 5-Fold CV for K: 20; lam: 0.00005: train_rmse: 0.676, valid_rmse: 0.788
# 5-Fold CV for K: 20; lam: 0.00005: train_rmse: 0.675, valid_rmse: 0.777
# 5-Fold CV for K: 20; lam: 0.00005: train_rmse: 0.673, valid_rmse: 0.790
# 5-Fold CV for K: 20; lam: 0.00005: train_rmse: 0.673, valid_rmse: 0.782
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.655, valid_rmse: 0.787
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.654, valid_rmse: 0.790
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.651, valid_rmse: 0.789
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.657, valid_rmse: 0.787
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.654, valid_rmse: 0.782
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.653, valid_rmse: 0.794
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.655, valid_rmse: 0.792
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.654, valid_rmse: 0.783
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.652, valid_rmse: 0.787
# 5-Fold CV for K: 20; lam: 0.00001: train_rmse: 0.654, valid_rmse: 0.790
# 5-Fold CV for K: 20; lam: 0.00000: train_rmse: 0.651, valid_rmse: 0.800
# 5-Fold CV for K: 20; lam: 0.00000: train_rmse: 0.653, valid_rmse: 0.793
# 5-Fold CV for K: 20; lam: 0.00000: train_rmse: 0.652, valid_rmse: 0.798
# 5-Fold CV for K: 20; lam: 0.00000: train_rmse: 0.653, valid_rmse: 0.791
# 5-Fold CV for K: 20; lam: 0.00000: train_rmse: 0.653, valid_rmse: 0.793
# Fitting Reg-LFM: K: 20, lam: 0.00005
# Reg-LFM: ite: 0; diff: 0.786 RMSE: 0.983
# Reg-LFM: ite: 1; diff: 0.241 RMSE: 0.746
# Reg-LFM: ite: 2; diff: 0.044 RMSE: 0.713
# Reg-LFM: ite: 3; diff: 0.017 RMSE: 0.701
# Reg-LFM: ite: 4; diff: 0.008 RMSE: 0.695
# Reg-LFM: ite: 5; diff: 0.004 RMSE: 0.692
# Reg-LFM: ite: 6; diff: 0.003 RMSE: 0.690
# Reg-LFM: ite: 7; diff: 0.002 RMSE: 0.689
# Reg-LFM: ite: 8; diff: 0.001 RMSE: 0.688
# Reg-LFM: ite: 9; diff: 0.001 RMSE: 0.688

# %%
def adjust(pred_rating, score_min, score_max):
    pred_rating_adjusted = pred_rating.copy()
    pred_rating_adjusted[pred_rating > score_max] = score_max
    pred_rating_adjusted[pred_rating < score_min] = score_min
    return pred_rating_adjusted

# %%
aug_pair, aug_rating_res = np.vstack((train_pair, fake_pair)), np.hstack((train_rating_res, fake_rating))

sSVD=LFM(n_user, n_item, K=20, lam=0.00005,iterNum=30)
sSVD.fit(aug_pair, aug_rating_res)
pred = pred + sSVD.predict(test_pair)
pred_rating = pred

pred_rating = adjust(pred_rating, 0, 15)
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_sLFM_20_bestlam.csv', index=False)
# Out:
# Fitting Reg-LFM: K: 20, lam: 0.00005
# Reg-LFM: ite: 0; diff: 0.788 RMSE: 0.976
# Reg-LFM: ite: 1; diff: 0.240 RMSE: 0.741
# Reg-LFM: ite: 2; diff: 0.040 RMSE: 0.711
# Reg-LFM: ite: 3; diff: 0.015 RMSE: 0.701
# Reg-LFM: ite: 4; diff: 0.008 RMSE: 0.695
# Reg-LFM: ite: 5; diff: 0.005 RMSE: 0.692
# Reg-LFM: ite: 6; diff: 0.003 RMSE: 0.690
# Reg-LFM: ite: 7; diff: 0.002 RMSE: 0.689
# Reg-LFM: ite: 8; diff: 0.002 RMSE: 0.688
# Reg-LFM: ite: 9; diff: 0.001 RMSE: 0.687
# Reg-LFM: ite: 10; diff: 0.001 RMSE: 0.686
# Reg-LFM: ite: 11; diff: 0.001 RMSE: 0.685
# Reg-LFM: ite: 12; diff: 0.001 RMSE: 0.685
# Reg-LFM: ite: 13; diff: 0.001 RMSE: 0.685
# Reg-LFM: ite: 14; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 15; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 16; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 17; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 18; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 19; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 20; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 21; diff: 0.000 RMSE: 0.683
# Reg-LFM: ite: 22; diff: 0.000 RMSE: 0.683
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 4.511090338700471
#    item    rating
#  604A4B  6.681115
#  F89A64  5.579994
#  A98D40  5.565581
#  E36CD5  4.511090
#  4BC7F1  3.266683

# %%
K=20
lam=0.0001
aug_pair, aug_rating_res = np.vstack((train_pair, fake_pair)), np.hstack((train_rating_res, fake_rating))
sSVD=LFM(n_user, n_item, K=K, lam=lam,iterNum=20)
sSVD.fit(aug_pair, aug_rating_res)
pred = pred + sSVD.predict(test_pair)
pred_rating = pred

## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_sLFM3.csv', index=False)
# Out:
# Fitting Reg-LFM: K: 20, lam: 0.00010
# Reg-LFM: ite: 0; diff: 0.780 RMSE: 1.002
# Reg-LFM: ite: 1; diff: 0.197 RMSE: 0.805
# Reg-LFM: ite: 2; diff: 0.061 RMSE: 0.756
# Reg-LFM: ite: 3; diff: 0.016 RMSE: 0.744
# Reg-LFM: ite: 4; diff: 0.007 RMSE: 0.739
# Reg-LFM: ite: 5; diff: 0.004 RMSE: 0.736
# Reg-LFM: ite: 6; diff: 0.002 RMSE: 0.734
# Reg-LFM: ite: 7; diff: 0.001 RMSE: 0.733
# Reg-LFM: ite: 8; diff: 0.001 RMSE: 0.733
# Reg-LFM: ite: 9; diff: 0.001 RMSE: 0.732
# Reg-LFM: ite: 10; diff: 0.001 RMSE: 0.732
# Reg-LFM: ite: 11; diff: 0.001 RMSE: 0.731
# Reg-LFM: ite: 12; diff: 0.000 RMSE: 0.731
# Reg-LFM: ite: 13; diff: 0.000 RMSE: 0.731
# Reg-LFM: ite: 14; diff: 0.000 RMSE: 0.730
# Reg-LFM: ite: 15; diff: 0.000 RMSE: 0.730
# Reg-LFM: ite: 16; diff: 0.000 RMSE: 0.730
# Reg-LFM: ite: 17; diff: 0.000 RMSE: 0.730
# Reg-LFM: ite: 18; diff: 0.000 RMSE: 0.730
# Reg-LFM: ite: 19; diff: 0.000 RMSE: 0.730
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 4.126704816501914
#    item    rating
#  604A4B  6.960940
#  F89A64  5.410425
#  A98D40  5.211507
#  E36CD5  4.126705
#  4BC7F1  3.049915

# %%
K=20
lam=0.0001
aug_pair, aug_rating_res = np.vstack((train_pair, fake_pair)), np.hstack((train_rating_res, fake_rating))
sSVD=LFM(n_user, n_item, K=K, lam=lam,iterNum=20)
sSVD.fit(aug_pair, aug_rating_res)
pred = pred + sSVD.predict(test_pair)
pred_rating = pred

## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_sLFM4.csv', index=False)
# Out:
# Fitting Reg-LFM: K: 20, lam: 0.00010
# Reg-LFM: ite: 0; diff: 0.782 RMSE: 1.004
# Reg-LFM: ite: 1; diff: 0.199 RMSE: 0.804
# Reg-LFM: ite: 2; diff: 0.064 RMSE: 0.752
# Reg-LFM: ite: 3; diff: 0.013 RMSE: 0.743
# Reg-LFM: ite: 4; diff: 0.006 RMSE: 0.738
# Reg-LFM: ite: 5; diff: 0.004 RMSE: 0.735
# Reg-LFM: ite: 6; diff: 0.003 RMSE: 0.733
# Reg-LFM: ite: 7; diff: 0.002 RMSE: 0.732
# Reg-LFM: ite: 8; diff: 0.001 RMSE: 0.731
# Reg-LFM: ite: 9; diff: 0.001 RMSE: 0.730
# Reg-LFM: ite: 10; diff: 0.001 RMSE: 0.730
# Reg-LFM: ite: 11; diff: 0.000 RMSE: 0.729
# Reg-LFM: ite: 12; diff: 0.000 RMSE: 0.729
# Reg-LFM: ite: 13; diff: 0.000 RMSE: 0.729
# Reg-LFM: ite: 14; diff: 0.000 RMSE: 0.729
# Reg-LFM: ite: 15; diff: 0.000 RMSE: 0.729
# Reg-LFM: ite: 16; diff: 0.000 RMSE: 0.729
# Reg-LFM: ite: 17; diff: 0.000 RMSE: 0.729
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 3.9417816008636475
#    item    rating
#  604A4B  7.220774
#  F89A64  5.338947
#  A98D40  4.977421
#  E36CD5  3.941782
#  4BC7F1  2.995635

# %%
K=20
lam=0.0001
aug_pair, aug_rating_res = np.vstack((train_pair, fake_pair)), np.hstack((train_rating_res, fake_rating))
sSVD=LFM(n_user, n_item, K=K, lam=lam)
sSVD.fit(aug_pair, aug_rating_res)
pred = pred + sSVD.predict(test_pair)
pred_rating = pred
# Out:
# Fitting Reg-LFM: K: 20, lam: 0.00010
# Reg-LFM: ite: 0; diff: 0.780 RMSE: 1.006
# Reg-LFM: ite: 1; diff: 0.202 RMSE: 0.804
# Reg-LFM: ite: 2; diff: 0.063 RMSE: 0.753
# Reg-LFM: ite: 3; diff: 0.014 RMSE: 0.742
# Reg-LFM: ite: 4; diff: 0.006 RMSE: 0.738
# Reg-LFM: ite: 5; diff: 0.003 RMSE: 0.735
# Reg-LFM: ite: 6; diff: 0.002 RMSE: 0.734
# Reg-LFM: ite: 7; diff: 0.002 RMSE: 0.733
# Reg-LFM: ite: 8; diff: 0.001 RMSE: 0.732
# Reg-LFM: ite: 9; diff: 0.001 RMSE: 0.731

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_sLFM2.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 4.340884837245671
#    item    rating
#  604A4B  6.815734
#  A98D40  5.669855
#  F89A64  5.575554
#  E36CD5  4.340885
#  4BC7F1  3.231248

# %%
aug_pair, aug_rating_res = np.vstack((train_pair, fake_pair)), np.hstack((train_rating_res, fake_rating))

Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(aug_pair, aug_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']

sSVD=LFM(n_user, n_item, K=best_K, lam=best_lam)
sSVD.fit(aug_pair, aug_rating_res)
pred = pred + sSVD.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.945, valid_rmse: 0.967
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.943, valid_rmse: 0.969
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.953, valid_rmse: 0.969
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.948, valid_rmse: 0.960
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.945, valid_rmse: 0.966
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.039
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.040
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.039
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.038, valid_rmse: 1.042
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.903, valid_rmse: 0.932
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.902, valid_rmse: 0.937
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.902, valid_rmse: 0.932
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.903, valid_rmse: 0.932
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.903, valid_rmse: 0.933
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.037, valid_rmse: 1.044
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 1.040, valid_rmse: 1.033
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.037, valid_rmse: 1.045
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.043
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.040, valid_rmse: 1.032
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.039
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.038, valid_rmse: 1.042
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.828, valid_rmse: 0.881
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.826, valid_rmse: 0.882
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.827, valid_rmse: 0.883
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.828, valid_rmse: 0.882
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.829, valid_rmse: 0.878
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 1.037, valid_rmse: 1.045
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 1.040, valid_rmse: 1.034
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.037, valid_rmse: 1.044
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.040, valid_rmse: 1.032
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.037, valid_rmse: 1.044
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.038, valid_rmse: 1.042
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.769, valid_rmse: 0.840
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.770, valid_rmse: 0.835
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.767, valid_rmse: 0.841
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.768, valid_rmse: 0.842
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.770, valid_rmse: 0.841
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.035
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.039
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 1.037, valid_rmse: 1.045
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.040, valid_rmse: 1.035
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.040, valid_rmse: 1.033
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.036
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.037, valid_rmse: 1.044
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.038, valid_rmse: 1.043
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.719, valid_rmse: 0.804
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.721, valid_rmse: 0.808
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.721, valid_rmse: 0.803
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.721, valid_rmse: 0.808
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.721, valid_rmse: 0.802
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 1.038, valid_rmse: 1.040
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 1.038, valid_rmse: 1.042
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 1.040, valid_rmse: 1.035
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 1.039, valid_rmse: 1.035
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.041
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.038, valid_rmse: 1.040
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.037
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.040, valid_rmse: 1.034
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.036, valid_rmse: 1.049
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.041, valid_rmse: 1.029
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.039, valid_rmse: 1.038
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.038, valid_rmse: 1.043
# Fitting Reg-LFM: K: 20, lam: 0.00010
# Reg-LFM: ite: 0; diff: 0.782 RMSE: 1.003
# Reg-LFM: ite: 1; diff: 0.201 RMSE: 0.801
# Reg-LFM: ite: 2; diff: 0.064 RMSE: 0.750
# Reg-LFM: ite: 3; diff: 0.013 RMSE: 0.740
# Reg-LFM: ite: 4; diff: 0.006 RMSE: 0.736
# Reg-LFM: ite: 5; diff: 0.003 RMSE: 0.734
# Reg-LFM: ite: 6; diff: 0.002 RMSE: 0.732
# Reg-LFM: ite: 7; diff: 0.001 RMSE: 0.731
# Reg-LFM: ite: 8; diff: 0.001 RMSE: 0.731
# Reg-LFM: ite: 9; diff: 0.001 RMSE: 0.730

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_sLFM.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 4.451172314340544
#    item    rating
#  604A4B  6.832671
#  A98D40  5.540618
#  F89A64  5.458220
#  E36CD5  4.451172
#  4BC7F1  3.101540

# %% [markdown]
# item_user_mean_LMF

# %%
## item mean + user_mean + LFM
## item_mean 
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred = item_ave.predict(test_pair)

## user_mean
train_rating_cm = train_rating - item_ave.predict(train_pair)
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - user_ave.predict(train_pair)
pred = pred + user_ave.predict(test_pair)

## fit user_mean + item_mean + LFM_CV by residual ratings 
Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.870, valid_rmse: 1.502
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.862, valid_rmse: 1.394
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.856, valid_rmse: 1.493
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.873, valid_rmse: 1.438
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.862, valid_rmse: 1.402
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.997, valid_rmse: 1.234
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.989, valid_rmse: 1.269
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.995, valid_rmse: 1.208
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.001, valid_rmse: 1.217
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.005, valid_rmse: 1.232
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.186, valid_rmse: 1.243
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.186, valid_rmse: 1.237
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.185, valid_rmse: 1.275
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.185, valid_rmse: 1.250
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.175, valid_rmse: 1.226
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.269, valid_rmse: 1.262
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.276, valid_rmse: 1.236
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.255, valid_rmse: 1.316
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.271, valid_rmse: 1.254
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.267, valid_rmse: 1.269
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.664, valid_rmse: 1.487
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.667, valid_rmse: 1.437
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.677, valid_rmse: 1.623
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.681, valid_rmse: 1.532
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.676, valid_rmse: 1.509
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.897, valid_rmse: 1.216
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.899, valid_rmse: 1.211
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.892, valid_rmse: 1.247
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.891, valid_rmse: 1.197
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.897, valid_rmse: 1.163
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.161, valid_rmse: 1.265
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.175, valid_rmse: 1.209
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.169, valid_rmse: 1.240
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.157, valid_rmse: 1.262
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.173, valid_rmse: 1.223
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.270, valid_rmse: 1.259
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.259, valid_rmse: 1.301
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.271, valid_rmse: 1.256
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.266, valid_rmse: 1.274
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.273, valid_rmse: 1.248
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.367, valid_rmse: 1.533
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.369, valid_rmse: 1.533
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.373, valid_rmse: 1.513
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.370, valid_rmse: 1.583
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.361, valid_rmse: 1.552
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.791, valid_rmse: 1.173
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.783, valid_rmse: 1.176
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.779, valid_rmse: 1.157
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.790, valid_rmse: 1.173
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.778, valid_rmse: 1.167
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.156, valid_rmse: 1.228
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.155, valid_rmse: 1.228
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.156, valid_rmse: 1.224
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.154, valid_rmse: 1.266
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.160, valid_rmse: 1.235
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.269, valid_rmse: 1.261
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.266, valid_rmse: 1.275
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.272, valid_rmse: 1.253
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.265, valid_rmse: 1.277
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.266, valid_rmse: 1.274
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.249, valid_rmse: 1.372
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.248, valid_rmse: 1.412
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.247, valid_rmse: 1.418
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.247, valid_rmse: 1.423
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.246, valid_rmse: 1.385
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.745, valid_rmse: 1.141
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.746, valid_rmse: 1.144
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.751, valid_rmse: 1.146
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.745, valid_rmse: 1.184
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.748, valid_rmse: 1.149
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.152, valid_rmse: 1.215
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.152, valid_rmse: 1.202
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.149, valid_rmse: 1.266
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.147, valid_rmse: 1.265
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.155, valid_rmse: 1.230
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.270, valid_rmse: 1.259
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.275, valid_rmse: 1.237
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.263, valid_rmse: 1.287
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.263, valid_rmse: 1.287
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.268, valid_rmse: 1.268
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.209, valid_rmse: 1.274
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.208, valid_rmse: 1.302
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.209, valid_rmse: 1.333
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.208, valid_rmse: 1.244
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.208, valid_rmse: 1.261
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.735, valid_rmse: 1.176
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.734, valid_rmse: 1.172
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.733, valid_rmse: 1.103
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.734, valid_rmse: 1.135
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.734, valid_rmse: 1.180
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.153, valid_rmse: 1.242
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.150, valid_rmse: 1.240
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.142, valid_rmse: 1.239
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.151, valid_rmse: 1.246
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.149, valid_rmse: 1.215
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.270, valid_rmse: 1.259
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.271, valid_rmse: 1.254
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.260, valid_rmse: 1.300
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.268, valid_rmse: 1.266
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.270, valid_rmse: 1.259
# Fitting Reg-LFM: K: 15, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.739 RMSE: 1.063
# Reg-LFM: ite: 1; diff: 0.105 RMSE: 0.951
# Reg-LFM: ite: 2; diff: 0.071 RMSE: 0.884
# Reg-LFM: ite: 3; diff: 0.040 RMSE: 0.849
# Reg-LFM: ite: 4; diff: 0.023 RMSE: 0.829
# Reg-LFM: ite: 5; diff: 0.015 RMSE: 0.817
# Reg-LFM: ite: 6; diff: 0.010 RMSE: 0.809
# Reg-LFM: ite: 7; diff: 0.007 RMSE: 0.803
# Reg-LFM: ite: 8; diff: 0.005 RMSE: 0.798
# Reg-LFM: ite: 9; diff: 0.004 RMSE: 0.796

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/item_user_mean_LFM.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 3.699872847611943
#   item   rating
# 4BC7F1 6.904534
# E36CD5 5.675935
# 604A4B 3.699873
# A98D40 3.223570
# F89A64 2.013034

# %% [markdown]
# GLB_item_user_mean_LMF

# %%
# glb mean
glb_ave = glb_mean()
glb_ave.fit(train_rating)
pred = glb_ave.predict(test_pair)

# item_mean
train_rating_res = train_rating - glb_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_res)
pred = pred + item_ave.predict(test_pair)

# user_mean
train_rating_res -= item_ave.predict(train_pair)
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating_res)
train_rating_res -= user_ave.predict(train_pair)
pred = pred + user_ave.predict(test_pair)

# fit GLB + user_mean + item_mean + LFM_CV by residual ratings 
Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.864, valid_rmse: 1.443
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.866, valid_rmse: 1.423
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.862, valid_rmse: 1.488
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.860, valid_rmse: 1.453
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.864, valid_rmse: 1.417
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.994, valid_rmse: 1.234
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.988, valid_rmse: 1.224
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.997, valid_rmse: 1.260
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.012, valid_rmse: 1.258
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 1.002, valid_rmse: 1.231
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.179, valid_rmse: 1.255
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.176, valid_rmse: 1.234
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.185, valid_rmse: 1.239
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.176, valid_rmse: 1.256
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.178, valid_rmse: 1.233
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.264, valid_rmse: 1.282
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.266, valid_rmse: 1.273
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.266, valid_rmse: 1.273
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.272, valid_rmse: 1.251
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.270, valid_rmse: 1.259
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.655, valid_rmse: 1.437
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.677, valid_rmse: 1.584
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.666, valid_rmse: 1.518
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.669, valid_rmse: 1.490
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.662, valid_rmse: 1.467
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.884, valid_rmse: 1.199
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.894, valid_rmse: 1.229
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.898, valid_rmse: 1.193
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.906, valid_rmse: 1.219
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.887, valid_rmse: 1.164
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.161, valid_rmse: 1.244
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.169, valid_rmse: 1.228
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.162, valid_rmse: 1.244
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.165, valid_rmse: 1.251
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.164, valid_rmse: 1.235
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.265, valid_rmse: 1.278
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.270, valid_rmse: 1.260
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.264, valid_rmse: 1.282
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.268, valid_rmse: 1.266
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.272, valid_rmse: 1.252
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.369, valid_rmse: 1.530
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.367, valid_rmse: 1.526
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.368, valid_rmse: 1.523
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.366, valid_rmse: 1.606
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.364, valid_rmse: 1.511
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.780, valid_rmse: 1.164
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.783, valid_rmse: 1.147
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.777, valid_rmse: 1.148
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.789, valid_rmse: 1.178
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.784, valid_rmse: 1.163
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.157, valid_rmse: 1.240
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.156, valid_rmse: 1.246
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.155, valid_rmse: 1.218
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.149, valid_rmse: 1.244
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.159, valid_rmse: 1.237
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.274, valid_rmse: 1.242
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.273, valid_rmse: 1.246
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.271, valid_rmse: 1.255
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.259, valid_rmse: 1.300
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.261, valid_rmse: 1.295
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.245, valid_rmse: 1.364
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.246, valid_rmse: 1.388
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.251, valid_rmse: 1.389
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.248, valid_rmse: 1.407
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.247, valid_rmse: 1.445
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.747, valid_rmse: 1.172
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.751, valid_rmse: 1.134
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.753, valid_rmse: 1.122
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.744, valid_rmse: 1.181
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.744, valid_rmse: 1.149
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.149, valid_rmse: 1.239
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.149, valid_rmse: 1.255
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.154, valid_rmse: 1.221
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.157, valid_rmse: 1.249
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.149, valid_rmse: 1.212
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.273, valid_rmse: 1.248
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.276, valid_rmse: 1.232
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.264, valid_rmse: 1.283
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.267, valid_rmse: 1.272
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.259, valid_rmse: 1.303
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.208, valid_rmse: 1.275
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.207, valid_rmse: 1.316
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.210, valid_rmse: 1.302
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.208, valid_rmse: 1.286
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.207, valid_rmse: 1.278
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.733, valid_rmse: 1.149
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.737, valid_rmse: 1.133
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.731, valid_rmse: 1.189
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.737, valid_rmse: 1.150
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.736, valid_rmse: 1.165
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.145, valid_rmse: 1.251
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.150, valid_rmse: 1.232
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.146, valid_rmse: 1.257
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.154, valid_rmse: 1.204
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.155, valid_rmse: 1.231
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.265, valid_rmse: 1.279
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.267, valid_rmse: 1.272
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.267, valid_rmse: 1.272
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.266, valid_rmse: 1.276
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.275, valid_rmse: 1.239
# Fitting Reg-LFM: K: 15, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.742 RMSE: 1.056
# Reg-LFM: ite: 1; diff: 0.104 RMSE: 0.946
# Reg-LFM: ite: 2; diff: 0.071 RMSE: 0.879
# Reg-LFM: ite: 3; diff: 0.039 RMSE: 0.844
# Reg-LFM: ite: 4; diff: 0.023 RMSE: 0.825
# Reg-LFM: ite: 5; diff: 0.015 RMSE: 0.812
# Reg-LFM: ite: 6; diff: 0.010 RMSE: 0.804
# Reg-LFM: ite: 7; diff: 0.006 RMSE: 0.799
# Reg-LFM: ite: 8; diff: 0.004 RMSE: 0.796
# Reg-LFM: ite: 9; diff: 0.003 RMSE: 0.793

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/GLB_item_user_mean_LFM.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 3.721348496876555
#   item   rating
# 4BC7F1 6.914685
# E36CD5 5.597167
# 604A4B 3.721348
# A98D40 3.112566
# F89A64 1.986474

# %% [markdown]
# GLB_user_item_mean_LMF

# %%
# glb mean
glb_ave = glb_mean()
glb_ave.fit(train_rating)
pred = glb_ave.predict(test_pair)

# user_mean
train_rating_res = train_rating - glb_ave.predict(train_pair)
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating_res)
pred = pred + user_ave.predict(test_pair)

# item_mean
train_rating_res -=  user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_res)
pred = pred + item_ave.predict(test_pair)


# fit GLB + user_mean + item_mean + LFM_CV by residual ratings 
Ks, lams = [3,5,10,15,20],[0.0001,0.0005,0.001,0.01]
shiing_cv = LFM_CV(n_user, n_item, cv=5, Ks=Ks, lams=lams)
shiing_cv.grid_search(train_pair, train_rating_res)
shiing_cv.plot_grid('valid')
shiing_cv.plot_grid('train')

## refit the best model, and make prediction
best_K, best_lam = int(shiing_cv.best_model['K']), shiing_cv.best_model['lam']
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair, train_rating_res)
pred = pred + shiing.predict(test_pair)
pred_rating = pred
# Out:
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.812, valid_rmse: 1.415
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.803, valid_rmse: 1.341
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.809, valid_rmse: 1.330
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.813, valid_rmse: 1.407
# 5-Fold CV for K: 3; lam: 0.00010: train_rmse: 0.793, valid_rmse: 1.358
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.972, valid_rmse: 1.271
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.973, valid_rmse: 1.291
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.980, valid_rmse: 1.263
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.969, valid_rmse: 1.260
# 5-Fold CV for K: 3; lam: 0.00050: train_rmse: 0.965, valid_rmse: 1.298
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.215, valid_rmse: 1.389
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.230, valid_rmse: 1.320
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.231, valid_rmse: 1.354
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.220, valid_rmse: 1.407
# 5-Fold CV for K: 3; lam: 0.00100: train_rmse: 1.229, valid_rmse: 1.375
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.876, valid_rmse: 1.903
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.870, valid_rmse: 1.926
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.895, valid_rmse: 1.826
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.893, valid_rmse: 1.837
# 5-Fold CV for K: 3; lam: 0.01000: train_rmse: 1.874, valid_rmse: 1.914
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.636, valid_rmse: 1.507
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.630, valid_rmse: 1.438
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.624, valid_rmse: 1.484
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.620, valid_rmse: 1.468
# 5-Fold CV for K: 5; lam: 0.00010: train_rmse: 0.616, valid_rmse: 1.428
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.878, valid_rmse: 1.267
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.885, valid_rmse: 1.250
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.875, valid_rmse: 1.265
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.882, valid_rmse: 1.299
# 5-Fold CV for K: 5; lam: 0.00050: train_rmse: 0.885, valid_rmse: 1.237
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.216, valid_rmse: 1.369
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.214, valid_rmse: 1.336
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.204, valid_rmse: 1.353
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.202, valid_rmse: 1.403
# 5-Fold CV for K: 5; lam: 0.00100: train_rmse: 1.206, valid_rmse: 1.384
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.890, valid_rmse: 1.846
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.879, valid_rmse: 1.893
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.879, valid_rmse: 1.893
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.878, valid_rmse: 1.897
# 5-Fold CV for K: 5; lam: 0.01000: train_rmse: 1.882, valid_rmse: 1.879
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.341, valid_rmse: 1.502
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.342, valid_rmse: 1.545
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.351, valid_rmse: 1.514
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.343, valid_rmse: 1.527
# 5-Fold CV for K: 10; lam: 0.00010: train_rmse: 0.352, valid_rmse: 1.552
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.784, valid_rmse: 1.244
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.780, valid_rmse: 1.246
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.786, valid_rmse: 1.272
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.780, valid_rmse: 1.285
# 5-Fold CV for K: 10; lam: 0.00050: train_rmse: 0.782, valid_rmse: 1.235
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.191, valid_rmse: 1.357
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.193, valid_rmse: 1.356
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.199, valid_rmse: 1.343
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.200, valid_rmse: 1.384
# 5-Fold CV for K: 10; lam: 0.00100: train_rmse: 1.197, valid_rmse: 1.402
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.881, valid_rmse: 1.884
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.879, valid_rmse: 1.891
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.866, valid_rmse: 1.942
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.894, valid_rmse: 1.833
# 5-Fold CV for K: 10; lam: 0.01000: train_rmse: 1.888, valid_rmse: 1.856
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.236, valid_rmse: 1.448
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.238, valid_rmse: 1.448
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.239, valid_rmse: 1.461
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.238, valid_rmse: 1.440
# 5-Fold CV for K: 15; lam: 0.00010: train_rmse: 0.235, valid_rmse: 1.463
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.750, valid_rmse: 1.207
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.748, valid_rmse: 1.227
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.751, valid_rmse: 1.305
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.747, valid_rmse: 1.270
# 5-Fold CV for K: 15; lam: 0.00050: train_rmse: 0.751, valid_rmse: 1.246
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.191, valid_rmse: 1.381
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.193, valid_rmse: 1.342
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.190, valid_rmse: 1.413
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.197, valid_rmse: 1.356
# 5-Fold CV for K: 15; lam: 0.00100: train_rmse: 1.192, valid_rmse: 1.347
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.885, valid_rmse: 1.869
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.882, valid_rmse: 1.881
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.874, valid_rmse: 1.911
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.887, valid_rmse: 1.861
# 5-Fold CV for K: 15; lam: 0.01000: train_rmse: 1.880, valid_rmse: 1.887
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.204, valid_rmse: 1.394
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.202, valid_rmse: 1.434
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.205, valid_rmse: 1.432
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.204, valid_rmse: 1.369
# 5-Fold CV for K: 20; lam: 0.00010: train_rmse: 0.203, valid_rmse: 1.354
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.739, valid_rmse: 1.250
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.736, valid_rmse: 1.287
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.735, valid_rmse: 1.288
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.735, valid_rmse: 1.213
# 5-Fold CV for K: 20; lam: 0.00050: train_rmse: 0.737, valid_rmse: 1.247
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.192, valid_rmse: 1.349
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.191, valid_rmse: 1.342
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.194, valid_rmse: 1.366
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.190, valid_rmse: 1.405
# 5-Fold CV for K: 20; lam: 0.00100: train_rmse: 1.185, valid_rmse: 1.382
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.874, valid_rmse: 1.913
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.888, valid_rmse: 1.857
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.875, valid_rmse: 1.909
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.891, valid_rmse: 1.845
# 5-Fold CV for K: 20; lam: 0.01000: train_rmse: 1.881, valid_rmse: 1.884
# Fitting Reg-LFM: K: 15, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.704 RMSE: 1.291
# Reg-LFM: ite: 1; diff: 0.290 RMSE: 0.917
# Reg-LFM: ite: 2; diff: 0.046 RMSE: 0.875
# Reg-LFM: ite: 3; diff: 0.029 RMSE: 0.850
# Reg-LFM: ite: 4; diff: 0.021 RMSE: 0.832
# Reg-LFM: ite: 5; diff: 0.014 RMSE: 0.820
# Reg-LFM: ite: 6; diff: 0.009 RMSE: 0.813
# Reg-LFM: ite: 7; diff: 0.007 RMSE: 0.807
# Reg-LFM: ite: 8; diff: 0.005 RMSE: 0.803
# Reg-LFM: ite: 9; diff: 0.004 RMSE: 0.800

# %%
## print T-th record and top-5 preferred items
print_T(2095,temp_test_pair,pred_rating)
print_top5(2095,temp_test_pair,pred_rating)

# submission
sub['rating'] = pred_rating
sub.to_csv('predict/GLB_user_item_mean_LFM.csv', index=False)
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 4.782893392498797
#   item   rating
# 604A4B 8.152251
# A98D40 6.855999
# F89A64 6.714650
# E36CD5 4.782893
# 4BC7F1 2.519099

# %%
### Note2: the computation complexity is not relative large for `augmentation step`, yet it might be solved by `SGD`.

# %%
class LFM(object):

    def __init__(self, n_user, n_item, lam=.001, K=10, iterNum=1000, tol=1e-4, verbose=1):
        self.P = np.random.randn(n_user, K)
        self.Q = np.random.randn(n_item, K)
        # self.index_item = []
        # self.index_user = []
        self.n_user = n_user
        self.n_item = n_item
        self.lam = lam
        self.K = K
        self.iterNum = iterNum
        self.tol = tol
        self.verbose = verbose

    def fit(self, train_pair, train_rating, learning_rate=0.0001):
        diff, tol = 1., self.tol
        n_user, n_item, n_obs = self.n_user, self.n_item, len(train_pair)
        K, iterNum, lam = self.K, self.iterNum, self.lam
        ## store user/item index set
        self.index_item = [np.where(train_pair[:,1] == i)[0] for i in range(n_item)]
        self.index_user = [np.where(train_pair[:,0] == u)[0] for u in range(n_user)]
        if self.verbose:
            print('Fitting Reg-LFM: K: %d, lam: %.5f' %(K, lam))
        for i in range(iterNum):
            ## item update
            score_old = self.rmse(test_pair=train_pair, test_rating=train_rating)
            for j in range(n_obs):
                user_id, item_id, rating_tmp = train_pair[j,0], train_pair[j,1], train_rating[j]
                err_tmp = rating_tmp - np.dot(self.P[user_id,:], self.Q[item_id,:])
                self.Q[item_id,:] = self.Q[item_id,:] + 2*learning_rate*err_tmp*self.P[user_id,:] - 2*learning_rate*lam*self.Q[item_id,:]
                err_tmp = rating_tmp - np.dot(self.P[user_id,:], self.Q[item_id,:])
                self.P[user_id,:] = self.P[user_id,:] + 2*learning_rate*self.Q[item_id,:] - 2*learning_rate*lam*self.P[user_id,:]
            # compute the new rmse score
            score_new = self.rmse(test_pair=train_pair, test_rating=train_rating)
            diff = - score_new + score_old
            if self.verbose:
                print("Reg-LFM: ite: %d; diff: %.3f RMSE: %.3f" %(i, diff, score_new))
            if (diff < tol):
                break

    def predict(self, test_pair):
        # predict ratings for user-item pairs
        pred_rating = [np.dot(self.P[line[0]], self.Q[line[1]]) for line in test_pair]
        return np.array(pred_rating)
    
    def rmse(self, test_pair, test_rating):
        # report the rmse for the fitted `LFM`
        pred_rating = self.predict(test_pair=test_pair)
        return np.sqrt( np.mean( (pred_rating - test_rating)**2) )

# %%
## Baseline + LFM
# glb mean
glb_ave = glb_mean()
glb_ave.fit(train_rating)
pred = glb_ave.predict(test_pair)

# user_mean
train_rating_cm = train_rating - glb_ave.predict(train_pair)
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - user_ave.predict(train_pair)
pred = pred + user_ave.predict(test_pair)

## item_mean
train_rating_cm = train_rating_cm - user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred = pred + item_ave.predict(test_pair)

## refit the best model, and make prediction
shiing=LFM(n_user, n_item, K=best_K, lam=best_lam)
shiing.fit(train_pair=train_pair, train_rating=train_rating_res, learning_rate=.001)
pred = pred + shiing.predict(test_pair)
# Out:
# Fitting Reg-LFM: K: 20, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.353 RMSE: 4.167
# Reg-LFM: ite: 1; diff: 0.306 RMSE: 3.862
# Reg-LFM: ite: 2; diff: 0.267 RMSE: 3.595
# Reg-LFM: ite: 3; diff: 0.233 RMSE: 3.362
# Reg-LFM: ite: 4; diff: 0.205 RMSE: 3.156
# Reg-LFM: ite: 5; diff: 0.181 RMSE: 2.975
# Reg-LFM: ite: 6; diff: 0.161 RMSE: 2.814
# Reg-LFM: ite: 7; diff: 0.143 RMSE: 2.670
# Reg-LFM: ite: 8; diff: 0.128 RMSE: 2.542
# Reg-LFM: ite: 9; diff: 0.115 RMSE: 2.427
# Reg-LFM: ite: 10; diff: 0.104 RMSE: 2.323
# Reg-LFM: ite: 11; diff: 0.094 RMSE: 2.229
# Reg-LFM: ite: 12; diff: 0.085 RMSE: 2.143
# Reg-LFM: ite: 13; diff: 0.078 RMSE: 2.065
# Reg-LFM: ite: 14; diff: 0.071 RMSE: 1.994
# Reg-LFM: ite: 15; diff: 0.065 RMSE: 1.929
# Reg-LFM: ite: 16; diff: 0.060 RMSE: 1.869
# Reg-LFM: ite: 17; diff: 0.055 RMSE: 1.814
# Reg-LFM: ite: 18; diff: 0.051 RMSE: 1.763
# Reg-LFM: ite: 19; diff: 0.047 RMSE: 1.715
# Reg-LFM: ite: 20; diff: 0.044 RMSE: 1.671
# Reg-LFM: ite: 21; diff: 0.041 RMSE: 1.631
# Reg-LFM: ite: 22; diff: 0.038 RMSE: 1.593
# Reg-LFM: ite: 23; diff: 0.036 RMSE: 1.557
# Reg-LFM: ite: 24; diff: 0.033 RMSE: 1.524
# Reg-LFM: ite: 25; diff: 0.031 RMSE: 1.493
# Reg-LFM: ite: 26; diff: 0.029 RMSE: 1.463
# Reg-LFM: ite: 27; diff: 0.028 RMSE: 1.436
# Reg-LFM: ite: 28; diff: 0.026 RMSE: 1.410
# Reg-LFM: ite: 29; diff: 0.024 RMSE: 1.386
# Reg-LFM: ite: 30; diff: 0.023 RMSE: 1.362
# Reg-LFM: ite: 31; diff: 0.022 RMSE: 1.341
# Reg-LFM: ite: 32; diff: 0.021 RMSE: 1.320
# Reg-LFM: ite: 33; diff: 0.020 RMSE: 1.300
# Reg-LFM: ite: 34; diff: 0.019 RMSE: 1.282
# Reg-LFM: ite: 35; diff: 0.018 RMSE: 1.264
# Reg-LFM: ite: 36; diff: 0.017 RMSE: 1.247
# Reg-LFM: ite: 37; diff: 0.016 RMSE: 1.231
# Reg-LFM: ite: 38; diff: 0.015 RMSE: 1.216
# Reg-LFM: ite: 39; diff: 0.015 RMSE: 1.202
# Reg-LFM: ite: 40; diff: 0.014 RMSE: 1.188
# Reg-LFM: ite: 41; diff: 0.013 RMSE: 1.175
# Reg-LFM: ite: 42; diff: 0.013 RMSE: 1.162
# Reg-LFM: ite: 43; diff: 0.012 RMSE: 1.150
# Reg-LFM: ite: 44; diff: 0.012 RMSE: 1.138
# Reg-LFM: ite: 45; diff: 0.011 RMSE: 1.127
# Reg-LFM: ite: 46; diff: 0.011 RMSE: 1.116
# Reg-LFM: ite: 47; diff: 0.010 RMSE: 1.106
# Reg-LFM: ite: 48; diff: 0.010 RMSE: 1.096
# Reg-LFM: ite: 49; diff: 0.010 RMSE: 1.086
# Reg-LFM: ite: 50; diff: 0.009 RMSE: 1.077
# Reg-LFM: ite: 51; diff: 0.009 RMSE: 1.068
# Reg-LFM: ite: 52; diff: 0.009 RMSE: 1.060
# Reg-LFM: ite: 53; diff: 0.008 RMSE: 1.052
# Reg-LFM: ite: 54; diff: 0.008 RMSE: 1.044
# Reg-LFM: ite: 55; diff: 0.008 RMSE: 1.036
# Reg-LFM: ite: 56; diff: 0.007 RMSE: 1.029
# Reg-LFM: ite: 57; diff: 0.007 RMSE: 1.022
# Reg-LFM: ite: 58; diff: 0.007 RMSE: 1.015
# Reg-LFM: ite: 59; diff: 0.007 RMSE: 1.008
# Reg-LFM: ite: 60; diff: 0.006 RMSE: 1.002
# Reg-LFM: ite: 61; diff: 0.006 RMSE: 0.995
# Reg-LFM: ite: 62; diff: 0.006 RMSE: 0.989
# Reg-LFM: ite: 63; diff: 0.006 RMSE: 0.983
# Reg-LFM: ite: 64; diff: 0.006 RMSE: 0.977
# Reg-LFM: ite: 65; diff: 0.006 RMSE: 0.972
# Reg-LFM: ite: 66; diff: 0.005 RMSE: 0.966
# Reg-LFM: ite: 67; diff: 0.005 RMSE: 0.961
# Reg-LFM: ite: 68; diff: 0.005 RMSE: 0.956
# Reg-LFM: ite: 69; diff: 0.005 RMSE: 0.951
# Reg-LFM: ite: 70; diff: 0.005 RMSE: 0.946
# Reg-LFM: ite: 71; diff: 0.005 RMSE: 0.942
# Reg-LFM: ite: 72; diff: 0.005 RMSE: 0.937
# Reg-LFM: ite: 73; diff: 0.004 RMSE: 0.932
# Reg-LFM: ite: 74; diff: 0.004 RMSE: 0.928
# Reg-LFM: ite: 75; diff: 0.004 RMSE: 0.924
# Reg-LFM: ite: 76; diff: 0.004 RMSE: 0.920
# Reg-LFM: ite: 77; diff: 0.004 RMSE: 0.916
# Reg-LFM: ite: 78; diff: 0.004 RMSE: 0.912
# Reg-LFM: ite: 79; diff: 0.004 RMSE: 0.908
# Reg-LFM: ite: 80; diff: 0.004 RMSE: 0.904
# Reg-LFM: ite: 81; diff: 0.004 RMSE: 0.901
# Reg-LFM: ite: 82; diff: 0.004 RMSE: 0.897
# Reg-LFM: ite: 83; diff: 0.003 RMSE: 0.893
# Reg-LFM: ite: 84; diff: 0.003 RMSE: 0.890
# Reg-LFM: ite: 85; diff: 0.003 RMSE: 0.887
# Reg-LFM: ite: 86; diff: 0.003 RMSE: 0.883
# Reg-LFM: ite: 87; diff: 0.003 RMSE: 0.880
# Reg-LFM: ite: 88; diff: 0.003 RMSE: 0.877
# Reg-LFM: ite: 89; diff: 0.003 RMSE: 0.874
# Reg-LFM: ite: 90; diff: 0.003 RMSE: 0.871
# Reg-LFM: ite: 91; diff: 0.003 RMSE: 0.868
# Reg-LFM: ite: 92; diff: 0.003 RMSE: 0.865
# Reg-LFM: ite: 93; diff: 0.003 RMSE: 0.862
# Reg-LFM: ite: 94; diff: 0.003 RMSE: 0.860
# Reg-LFM: ite: 95; diff: 0.003 RMSE: 0.857
# Reg-LFM: ite: 96; diff: 0.003 RMSE: 0.854
# Reg-LFM: ite: 97; diff: 0.003 RMSE: 0.852
# Reg-LFM: ite: 98; diff: 0.003 RMSE: 0.849
# Reg-LFM: ite: 99; diff: 0.002 RMSE: 0.847
# Reg-LFM: ite: 100; diff: 0.002 RMSE: 0.844
# Reg-LFM: ite: 101; diff: 0.002 RMSE: 0.842
# Reg-LFM: ite: 102; diff: 0.002 RMSE: 0.839
# Reg-LFM: ite: 103; diff: 0.002 RMSE: 0.837
# Reg-LFM: ite: 104; diff: 0.002 RMSE: 0.835
# Reg-LFM: ite: 105; diff: 0.002 RMSE: 0.833
# Reg-LFM: ite: 106; diff: 0.002 RMSE: 0.830
# Reg-LFM: ite: 107; diff: 0.002 RMSE: 0.828
# Reg-LFM: ite: 108; diff: 0.002 RMSE: 0.826
# Reg-LFM: ite: 109; diff: 0.002 RMSE: 0.824
# Reg-LFM: ite: 110; diff: 0.002 RMSE: 0.822
# Reg-LFM: ite: 111; diff: 0.002 RMSE: 0.820
# Reg-LFM: ite: 112; diff: 0.002 RMSE: 0.818
# Reg-LFM: ite: 113; diff: 0.002 RMSE: 0.816
# Reg-LFM: ite: 114; diff: 0.002 RMSE: 0.814
# Reg-LFM: ite: 115; diff: 0.002 RMSE: 0.812
# Reg-LFM: ite: 116; diff: 0.002 RMSE: 0.811
# Reg-LFM: ite: 117; diff: 0.002 RMSE: 0.809
# Reg-LFM: ite: 118; diff: 0.002 RMSE: 0.807
# Reg-LFM: ite: 119; diff: 0.002 RMSE: 0.805
# Reg-LFM: ite: 120; diff: 0.002 RMSE: 0.803
# Reg-LFM: ite: 121; diff: 0.002 RMSE: 0.802
# Reg-LFM: ite: 122; diff: 0.002 RMSE: 0.800
# Reg-LFM: ite: 123; diff: 0.002 RMSE: 0.798
# Reg-LFM: ite: 124; diff: 0.002 RMSE: 0.797
# Reg-LFM: ite: 125; diff: 0.002 RMSE: 0.795
# Reg-LFM: ite: 126; diff: 0.002 RMSE: 0.794
# Reg-LFM: ite: 127; diff: 0.002 RMSE: 0.792
# Reg-LFM: ite: 128; diff: 0.002 RMSE: 0.791
# Reg-LFM: ite: 129; diff: 0.001 RMSE: 0.789
# Reg-LFM: ite: 130; diff: 0.001 RMSE: 0.788
# Reg-LFM: ite: 131; diff: 0.001 RMSE: 0.786
# Reg-LFM: ite: 132; diff: 0.001 RMSE: 0.785
# Reg-LFM: ite: 133; diff: 0.001 RMSE: 0.783
# Reg-LFM: ite: 134; diff: 0.001 RMSE: 0.782
# Reg-LFM: ite: 135; diff: 0.001 RMSE: 0.781
# Reg-LFM: ite: 136; diff: 0.001 RMSE: 0.779
# Reg-LFM: ite: 137; diff: 0.001 RMSE: 0.778
# Reg-LFM: ite: 138; diff: 0.001 RMSE: 0.777
# Reg-LFM: ite: 139; diff: 0.001 RMSE: 0.776
# Reg-LFM: ite: 140; diff: 0.001 RMSE: 0.774
# Reg-LFM: ite: 141; diff: 0.001 RMSE: 0.773
# Reg-LFM: ite: 142; diff: 0.001 RMSE: 0.772
# Reg-LFM: ite: 143; diff: 0.001 RMSE: 0.771
# Reg-LFM: ite: 144; diff: 0.001 RMSE: 0.770
# Reg-LFM: ite: 145; diff: 0.001 RMSE: 0.768
# Reg-LFM: ite: 146; diff: 0.001 RMSE: 0.767
# Reg-LFM: ite: 147; diff: 0.001 RMSE: 0.766
# Reg-LFM: ite: 148; diff: 0.001 RMSE: 0.765
# Reg-LFM: ite: 149; diff: 0.001 RMSE: 0.764
# Reg-LFM: ite: 150; diff: 0.001 RMSE: 0.763
# Reg-LFM: ite: 151; diff: 0.001 RMSE: 0.762
# Reg-LFM: ite: 152; diff: 0.001 RMSE: 0.761
# Reg-LFM: ite: 153; diff: 0.001 RMSE: 0.760
# Reg-LFM: ite: 154; diff: 0.001 RMSE: 0.759
# Reg-LFM: ite: 155; diff: 0.001 RMSE: 0.758
# Reg-LFM: ite: 156; diff: 0.001 RMSE: 0.757
# Reg-LFM: ite: 157; diff: 0.001 RMSE: 0.756
# Reg-LFM: ite: 158; diff: 0.001 RMSE: 0.755
# Reg-LFM: ite: 159; diff: 0.001 RMSE: 0.754
# Reg-LFM: ite: 160; diff: 0.001 RMSE: 0.753
# Reg-LFM: ite: 161; diff: 0.001 RMSE: 0.752
# Reg-LFM: ite: 162; diff: 0.001 RMSE: 0.751
# Reg-LFM: ite: 163; diff: 0.001 RMSE: 0.750
# Reg-LFM: ite: 164; diff: 0.001 RMSE: 0.750
# Reg-LFM: ite: 165; diff: 0.001 RMSE: 0.749
# Reg-LFM: ite: 166; diff: 0.001 RMSE: 0.748
# Reg-LFM: ite: 167; diff: 0.001 RMSE: 0.747
# Reg-LFM: ite: 168; diff: 0.001 RMSE: 0.746
# Reg-LFM: ite: 169; diff: 0.001 RMSE: 0.745
# Reg-LFM: ite: 170; diff: 0.001 RMSE: 0.745
# Reg-LFM: ite: 171; diff: 0.001 RMSE: 0.744
# Reg-LFM: ite: 172; diff: 0.001 RMSE: 0.743
# Reg-LFM: ite: 173; diff: 0.001 RMSE: 0.742
# Reg-LFM: ite: 174; diff: 0.001 RMSE: 0.742
# Reg-LFM: ite: 175; diff: 0.001 RMSE: 0.741
# Reg-LFM: ite: 176; diff: 0.001 RMSE: 0.740
# Reg-LFM: ite: 177; diff: 0.001 RMSE: 0.739
# Reg-LFM: ite: 178; diff: 0.001 RMSE: 0.739
# Reg-LFM: ite: 179; diff: 0.001 RMSE: 0.738
# Reg-LFM: ite: 180; diff: 0.001 RMSE: 0.737
# Reg-LFM: ite: 181; diff: 0.001 RMSE: 0.737
# Reg-LFM: ite: 182; diff: 0.001 RMSE: 0.736
# Reg-LFM: ite: 183; diff: 0.001 RMSE: 0.735
# Reg-LFM: ite: 184; diff: 0.001 RMSE: 0.735
# Reg-LFM: ite: 185; diff: 0.001 RMSE: 0.734
# Reg-LFM: ite: 186; diff: 0.001 RMSE: 0.733
# Reg-LFM: ite: 187; diff: 0.001 RMSE: 0.733
# Reg-LFM: ite: 188; diff: 0.001 RMSE: 0.732
# Reg-LFM: ite: 189; diff: 0.001 RMSE: 0.731
# Reg-LFM: ite: 190; diff: 0.001 RMSE: 0.731
# Reg-LFM: ite: 191; diff: 0.001 RMSE: 0.730
# Reg-LFM: ite: 192; diff: 0.001 RMSE: 0.730
# Reg-LFM: ite: 193; diff: 0.001 RMSE: 0.729
# Reg-LFM: ite: 194; diff: 0.001 RMSE: 0.728
# Reg-LFM: ite: 195; diff: 0.001 RMSE: 0.728
# Reg-LFM: ite: 196; diff: 0.001 RMSE: 0.727
# Reg-LFM: ite: 197; diff: 0.001 RMSE: 0.727
# Reg-LFM: ite: 198; diff: 0.001 RMSE: 0.726
# Reg-LFM: ite: 199; diff: 0.001 RMSE: 0.725
# Reg-LFM: ite: 200; diff: 0.001 RMSE: 0.725
# Reg-LFM: ite: 201; diff: 0.001 RMSE: 0.724
# Reg-LFM: ite: 202; diff: 0.001 RMSE: 0.724
# Reg-LFM: ite: 203; diff: 0.001 RMSE: 0.723
# Reg-LFM: ite: 204; diff: 0.001 RMSE: 0.723
# Reg-LFM: ite: 205; diff: 0.001 RMSE: 0.722
# Reg-LFM: ite: 206; diff: 0.001 RMSE: 0.722
# Reg-LFM: ite: 207; diff: 0.001 RMSE: 0.721
# Reg-LFM: ite: 208; diff: 0.001 RMSE: 0.720
# Reg-LFM: ite: 209; diff: 0.001 RMSE: 0.720
# Reg-LFM: ite: 210; diff: 0.001 RMSE: 0.719
# Reg-LFM: ite: 211; diff: 0.001 RMSE: 0.719
# Reg-LFM: ite: 212; diff: 0.001 RMSE: 0.718
# Reg-LFM: ite: 213; diff: 0.001 RMSE: 0.718
# Reg-LFM: ite: 214; diff: 0.001 RMSE: 0.717
# Reg-LFM: ite: 215; diff: 0.001 RMSE: 0.717
# Reg-LFM: ite: 216; diff: 0.001 RMSE: 0.716
# Reg-LFM: ite: 217; diff: 0.001 RMSE: 0.716
# Reg-LFM: ite: 218; diff: 0.001 RMSE: 0.715
# Reg-LFM: ite: 219; diff: 0.001 RMSE: 0.715
# Reg-LFM: ite: 220; diff: 0.001 RMSE: 0.714
# Reg-LFM: ite: 221; diff: 0.001 RMSE: 0.714
# Reg-LFM: ite: 222; diff: 0.001 RMSE: 0.713
# Reg-LFM: ite: 223; diff: 0.000 RMSE: 0.713
# Reg-LFM: ite: 224; diff: 0.000 RMSE: 0.712
# Reg-LFM: ite: 225; diff: 0.000 RMSE: 0.712
# Reg-LFM: ite: 226; diff: 0.000 RMSE: 0.711
# Reg-LFM: ite: 227; diff: 0.000 RMSE: 0.711
# Reg-LFM: ite: 228; diff: 0.000 RMSE: 0.710
# Reg-LFM: ite: 229; diff: 0.000 RMSE: 0.710
# Reg-LFM: ite: 230; diff: 0.000 RMSE: 0.709
# Reg-LFM: ite: 231; diff: 0.000 RMSE: 0.709
# Reg-LFM: ite: 232; diff: 0.000 RMSE: 0.708
# Reg-LFM: ite: 233; diff: 0.000 RMSE: 0.708
# Reg-LFM: ite: 234; diff: 0.000 RMSE: 0.707
# Reg-LFM: ite: 235; diff: 0.000 RMSE: 0.707
# Reg-LFM: ite: 236; diff: 0.000 RMSE: 0.706
# Reg-LFM: ite: 237; diff: 0.000 RMSE: 0.706
# Reg-LFM: ite: 238; diff: 0.000 RMSE: 0.705
# Reg-LFM: ite: 239; diff: 0.000 RMSE: 0.705
# Reg-LFM: ite: 240; diff: 0.000 RMSE: 0.704
# Reg-LFM: ite: 241; diff: 0.000 RMSE: 0.704
# Reg-LFM: ite: 242; diff: 0.000 RMSE: 0.704
# Reg-LFM: ite: 243; diff: 0.000 RMSE: 0.703
# Reg-LFM: ite: 244; diff: 0.000 RMSE: 0.703
# Reg-LFM: ite: 245; diff: 0.000 RMSE: 0.702
# Reg-LFM: ite: 246; diff: 0.000 RMSE: 0.702
# Reg-LFM: ite: 247; diff: 0.000 RMSE: 0.701
# Reg-LFM: ite: 248; diff: 0.000 RMSE: 0.701
# Reg-LFM: ite: 249; diff: 0.000 RMSE: 0.700
# Reg-LFM: ite: 250; diff: 0.000 RMSE: 0.700
# Reg-LFM: ite: 251; diff: 0.000 RMSE: 0.699
# Reg-LFM: ite: 252; diff: 0.000 RMSE: 0.699
# Reg-LFM: ite: 253; diff: 0.000 RMSE: 0.698
# Reg-LFM: ite: 254; diff: 0.000 RMSE: 0.698
# Reg-LFM: ite: 255; diff: 0.000 RMSE: 0.697
# Reg-LFM: ite: 256; diff: 0.000 RMSE: 0.697
# Reg-LFM: ite: 257; diff: 0.000 RMSE: 0.697
# Reg-LFM: ite: 258; diff: 0.000 RMSE: 0.696
# Reg-LFM: ite: 259; diff: 0.000 RMSE: 0.696
# Reg-LFM: ite: 260; diff: 0.000 RMSE: 0.695
# Reg-LFM: ite: 261; diff: 0.000 RMSE: 0.695
# Reg-LFM: ite: 262; diff: 0.000 RMSE: 0.694
# Reg-LFM: ite: 263; diff: 0.000 RMSE: 0.694
# Reg-LFM: ite: 264; diff: 0.000 RMSE: 0.693
# Reg-LFM: ite: 265; diff: 0.000 RMSE: 0.693
# Reg-LFM: ite: 266; diff: 0.000 RMSE: 0.693
# Reg-LFM: ite: 267; diff: 0.000 RMSE: 0.692
# Reg-LFM: ite: 268; diff: 0.000 RMSE: 0.692
# Reg-LFM: ite: 269; diff: 0.000 RMSE: 0.691
# Reg-LFM: ite: 270; diff: 0.000 RMSE: 0.691
# Reg-LFM: ite: 271; diff: 0.000 RMSE: 0.690
# Reg-LFM: ite: 272; diff: 0.000 RMSE: 0.690
# Reg-LFM: ite: 273; diff: 0.000 RMSE: 0.690
# Reg-LFM: ite: 274; diff: 0.000 RMSE: 0.689
# Reg-LFM: ite: 275; diff: 0.000 RMSE: 0.689
# Reg-LFM: ite: 276; diff: 0.000 RMSE: 0.688
# Reg-LFM: ite: 277; diff: 0.000 RMSE: 0.688
# Reg-LFM: ite: 278; diff: 0.000 RMSE: 0.687
# Reg-LFM: ite: 279; diff: 0.000 RMSE: 0.687
# Reg-LFM: ite: 280; diff: 0.000 RMSE: 0.687
# Reg-LFM: ite: 281; diff: 0.000 RMSE: 0.686
# Reg-LFM: ite: 282; diff: 0.000 RMSE: 0.686
# Reg-LFM: ite: 283; diff: 0.000 RMSE: 0.685
# Reg-LFM: ite: 284; diff: 0.000 RMSE: 0.685
# Reg-LFM: ite: 285; diff: 0.000 RMSE: 0.685
# Reg-LFM: ite: 286; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 287; diff: 0.000 RMSE: 0.684
# Reg-LFM: ite: 288; diff: 0.000 RMSE: 0.683
# Reg-LFM: ite: 289; diff: 0.000 RMSE: 0.683
# Reg-LFM: ite: 290; diff: 0.000 RMSE: 0.683
# Reg-LFM: ite: 291; diff: 0.000 RMSE: 0.682
# Reg-LFM: ite: 292; diff: 0.000 RMSE: 0.682
# Reg-LFM: ite: 293; diff: 0.000 RMSE: 0.681
# Reg-LFM: ite: 294; diff: 0.000 RMSE: 0.681
# Reg-LFM: ite: 295; diff: 0.000 RMSE: 0.681
# Reg-LFM: ite: 296; diff: 0.000 RMSE: 0.680
# Reg-LFM: ite: 297; diff: 0.000 RMSE: 0.680
# Reg-LFM: ite: 298; diff: 0.000 RMSE: 0.679
# Reg-LFM: ite: 299; diff: 0.000 RMSE: 0.679
# Reg-LFM: ite: 300; diff: 0.000 RMSE: 0.679
# Reg-LFM: ite: 301; diff: 0.000 RMSE: 0.678
# Reg-LFM: ite: 302; diff: 0.000 RMSE: 0.678
# Reg-LFM: ite: 303; diff: 0.000 RMSE: 0.678
# Reg-LFM: ite: 304; diff: 0.000 RMSE: 0.677
# Reg-LFM: ite: 305; diff: 0.000 RMSE: 0.677
# Reg-LFM: ite: 306; diff: 0.000 RMSE: 0.676
# Reg-LFM: ite: 307; diff: 0.000 RMSE: 0.676
# Reg-LFM: ite: 308; diff: 0.000 RMSE: 0.676
# Reg-LFM: ite: 309; diff: 0.000 RMSE: 0.675
# Reg-LFM: ite: 310; diff: 0.000 RMSE: 0.675
# Reg-LFM: ite: 311; diff: 0.000 RMSE: 0.675
# Reg-LFM: ite: 312; diff: 0.000 RMSE: 0.674
# Reg-LFM: ite: 313; diff: 0.000 RMSE: 0.674
# Reg-LFM: ite: 314; diff: 0.000 RMSE: 0.674
# Reg-LFM: ite: 315; diff: 0.000 RMSE: 0.673
# Reg-LFM: ite: 316; diff: 0.000 RMSE: 0.673
# Reg-LFM: ite: 317; diff: 0.000 RMSE: 0.673
# Reg-LFM: ite: 318; diff: 0.000 RMSE: 0.672
# Reg-LFM: ite: 319; diff: 0.000 RMSE: 0.672
# Reg-LFM: ite: 320; diff: 0.000 RMSE: 0.672
# Reg-LFM: ite: 321; diff: 0.000 RMSE: 0.671
# Reg-LFM: ite: 322; diff: 0.000 RMSE: 0.671
# Reg-LFM: ite: 323; diff: 0.000 RMSE: 0.671
# Reg-LFM: ite: 324; diff: 0.000 RMSE: 0.670
# Reg-LFM: ite: 325; diff: 0.000 RMSE: 0.670
# Reg-LFM: ite: 326; diff: 0.000 RMSE: 0.670
# Reg-LFM: ite: 327; diff: 0.000 RMSE: 0.669
# Reg-LFM: ite: 328; diff: 0.000 RMSE: 0.669
# Reg-LFM: ite: 329; diff: 0.000 RMSE: 0.669
# Reg-LFM: ite: 330; diff: 0.000 RMSE: 0.668
# Reg-LFM: ite: 331; diff: 0.000 RMSE: 0.668
# Reg-LFM: ite: 332; diff: 0.000 RMSE: 0.668
# Reg-LFM: ite: 333; diff: 0.000 RMSE: 0.667
# Reg-LFM: ite: 334; diff: 0.000 RMSE: 0.667
# Reg-LFM: ite: 335; diff: 0.000 RMSE: 0.667
# Reg-LFM: ite: 336; diff: 0.000 RMSE: 0.666
# Reg-LFM: ite: 337; diff: 0.000 RMSE: 0.666
# Reg-LFM: ite: 338; diff: 0.000 RMSE: 0.666
# Reg-LFM: ite: 339; diff: 0.000 RMSE: 0.666
# Reg-LFM: ite: 340; diff: 0.000 RMSE: 0.665
# Reg-LFM: ite: 341; diff: 0.000 RMSE: 0.665
# Reg-LFM: ite: 342; diff: 0.000 RMSE: 0.665
# Reg-LFM: ite: 343; diff: 0.000 RMSE: 0.665
# Reg-LFM: ite: 344; diff: 0.000 RMSE: 0.664
# Reg-LFM: ite: 345; diff: 0.000 RMSE: 0.664
# Reg-LFM: ite: 346; diff: 0.000 RMSE: 0.664
# Reg-LFM: ite: 347; diff: 0.000 RMSE: 0.663
# Reg-LFM: ite: 348; diff: 0.000 RMSE: 0.663
# Reg-LFM: ite: 349; diff: 0.000 RMSE: 0.663
# Reg-LFM: ite: 350; diff: 0.000 RMSE: 0.663
# Reg-LFM: ite: 351; diff: 0.000 RMSE: 0.663
# Reg-LFM: ite: 352; diff: 0.000 RMSE: 0.662
# Reg-LFM: ite: 353; diff: 0.000 RMSE: 0.662
# Reg-LFM: ite: 354; diff: 0.000 RMSE: 0.662
# Reg-LFM: ite: 355; diff: 0.000 RMSE: 0.662
# Reg-LFM: ite: 356; diff: 0.000 RMSE: 0.661
# Reg-LFM: ite: 357; diff: 0.000 RMSE: 0.661
# Reg-LFM: ite: 358; diff: 0.000 RMSE: 0.661
# Reg-LFM: ite: 359; diff: 0.000 RMSE: 0.661
# Reg-LFM: ite: 360; diff: 0.000 RMSE: 0.661
# Reg-LFM: ite: 361; diff: 0.000 RMSE: 0.660
# Reg-LFM: ite: 362; diff: 0.000 RMSE: 0.660
# Reg-LFM: ite: 363; diff: 0.000 RMSE: 0.660
# Reg-LFM: ite: 364; diff: 0.000 RMSE: 0.660
# Reg-LFM: ite: 365; diff: 0.000 RMSE: 0.660
# Reg-LFM: ite: 366; diff: 0.000 RMSE: 0.659
# Reg-LFM: ite: 367; diff: 0.000 RMSE: 0.659
# Reg-LFM: ite: 368; diff: 0.000 RMSE: 0.659
# Reg-LFM: ite: 369; diff: 0.000 RMSE: 0.659
# Reg-LFM: ite: 370; diff: 0.000 RMSE: 0.659
# Reg-LFM: ite: 371; diff: 0.000 RMSE: 0.659
# Reg-LFM: ite: 372; diff: 0.000 RMSE: 0.658
# Reg-LFM: ite: 373; diff: 0.000 RMSE: 0.658
# Reg-LFM: ite: 374; diff: 0.000 RMSE: 0.658
# Reg-LFM: ite: 375; diff: 0.000 RMSE: 0.658
# Reg-LFM: ite: 376; diff: 0.000 RMSE: 0.658
# Reg-LFM: ite: 377; diff: 0.000 RMSE: 0.658
# Reg-LFM: ite: 378; diff: 0.000 RMSE: 0.658
# Reg-LFM: ite: 379; diff: 0.000 RMSE: 0.657
# Reg-LFM: ite: 380; diff: 0.000 RMSE: 0.657
# Reg-LFM: ite: 381; diff: 0.000 RMSE: 0.657
# Reg-LFM: ite: 382; diff: 0.000 RMSE: 0.657
# Reg-LFM: ite: 383; diff: 0.000 RMSE: 0.657
# Reg-LFM: ite: 384; diff: 0.000 RMSE: 0.657
# Reg-LFM: ite: 385; diff: 0.000 RMSE: 0.657
# Reg-LFM: ite: 386; diff: 0.000 RMSE: 0.656
# Reg-LFM: ite: 387; diff: 0.000 RMSE: 0.656
# Reg-LFM: ite: 388; diff: 0.000 RMSE: 0.656
# Reg-LFM: ite: 389; diff: 0.000 RMSE: 0.656
# Reg-LFM: ite: 390; diff: 0.000 RMSE: 0.656
# Reg-LFM: ite: 391; diff: 0.000 RMSE: 0.656
# Reg-LFM: ite: 392; diff: 0.000 RMSE: 0.656
# Reg-LFM: ite: 393; diff: 0.000 RMSE: 0.656

# %%
# Make your prediction
# pred_rating is an array of your prediction for `dtest`
pred_rating = pred


# submission
sub['rating'] = pred_rating
sub.to_csv('GLB_user_item_mean_LFMSGD.csv', index=False)

## Then just submit sub1.csv to the competition in Kaggle

# %%
user_ave = user_mean(n_user=n_user)
user_ave.fit(train_pair=train_pair, train_ratings=train_rating)
pred = user_ave.predict(test_pair)

## item_mean
train_rating_cm = train_rating - user_ave.predict(train_pair)
item_ave = item_mean(n_item=n_item)
item_ave.fit(train_pair=train_pair, train_ratings=train_rating_cm)
train_rating_res = train_rating_cm - item_ave.predict(train_pair)
pred = pred + item_ave.predict(test_pair)
## refit the best model, and make prediction

shiing=LFM(n_user, n_item, K=3, lam=best_lam)
shiing.fit(train_pair=train_pair, train_rating=train_rating_res, learning_rate=.001)
pred = pred + shiing.predict(test_pair)
# Out:
# Fitting Reg-LFM: K: 3, lam: 0.00050
# Reg-LFM: ite: 0; diff: 0.086 RMSE: 2.075
# Reg-LFM: ite: 1; diff: 0.078 RMSE: 1.997
# Reg-LFM: ite: 2; diff: 0.071 RMSE: 1.926
# Reg-LFM: ite: 3; diff: 0.065 RMSE: 1.861
# Reg-LFM: ite: 4; diff: 0.059 RMSE: 1.802
# Reg-LFM: ite: 5; diff: 0.054 RMSE: 1.749
# Reg-LFM: ite: 6; diff: 0.049 RMSE: 1.700
# Reg-LFM: ite: 7; diff: 0.045 RMSE: 1.655
# Reg-LFM: ite: 8; diff: 0.041 RMSE: 1.614
# Reg-LFM: ite: 9; diff: 0.037 RMSE: 1.577
# Reg-LFM: ite: 10; diff: 0.034 RMSE: 1.543
# Reg-LFM: ite: 11; diff: 0.031 RMSE: 1.512
# Reg-LFM: ite: 12; diff: 0.029 RMSE: 1.483
# Reg-LFM: ite: 13; diff: 0.026 RMSE: 1.456
# Reg-LFM: ite: 14; diff: 0.024 RMSE: 1.432
# Reg-LFM: ite: 15; diff: 0.022 RMSE: 1.410
# Reg-LFM: ite: 16; diff: 0.021 RMSE: 1.389
# Reg-LFM: ite: 17; diff: 0.019 RMSE: 1.370
# Reg-LFM: ite: 18; diff: 0.018 RMSE: 1.352
# Reg-LFM: ite: 19; diff: 0.016 RMSE: 1.336
# Reg-LFM: ite: 20; diff: 0.015 RMSE: 1.321
# Reg-LFM: ite: 21; diff: 0.014 RMSE: 1.307
# Reg-LFM: ite: 22; diff: 0.013 RMSE: 1.294
# Reg-LFM: ite: 23; diff: 0.012 RMSE: 1.282
# Reg-LFM: ite: 24; diff: 0.011 RMSE: 1.271
# Reg-LFM: ite: 25; diff: 0.010 RMSE: 1.260
# Reg-LFM: ite: 26; diff: 0.010 RMSE: 1.250
# Reg-LFM: ite: 27; diff: 0.009 RMSE: 1.241
# Reg-LFM: ite: 28; diff: 0.008 RMSE: 1.233
# Reg-LFM: ite: 29; diff: 0.008 RMSE: 1.225
# Reg-LFM: ite: 30; diff: 0.007 RMSE: 1.218
# Reg-LFM: ite: 31; diff: 0.007 RMSE: 1.211
# Reg-LFM: ite: 32; diff: 0.006 RMSE: 1.204
# Reg-LFM: ite: 33; diff: 0.006 RMSE: 1.198
# Reg-LFM: ite: 34; diff: 0.006 RMSE: 1.192
# Reg-LFM: ite: 35; diff: 0.005 RMSE: 1.187
# Reg-LFM: ite: 36; diff: 0.005 RMSE: 1.182
# Reg-LFM: ite: 37; diff: 0.005 RMSE: 1.177
# Reg-LFM: ite: 38; diff: 0.004 RMSE: 1.173
# Reg-LFM: ite: 39; diff: 0.004 RMSE: 1.168
# Reg-LFM: ite: 40; diff: 0.004 RMSE: 1.164
# Reg-LFM: ite: 41; diff: 0.004 RMSE: 1.161
# Reg-LFM: ite: 42; diff: 0.004 RMSE: 1.157
# Reg-LFM: ite: 43; diff: 0.003 RMSE: 1.154
# Reg-LFM: ite: 44; diff: 0.003 RMSE: 1.151
# Reg-LFM: ite: 45; diff: 0.003 RMSE: 1.148
# Reg-LFM: ite: 46; diff: 0.003 RMSE: 1.145
# Reg-LFM: ite: 47; diff: 0.003 RMSE: 1.142
# Reg-LFM: ite: 48; diff: 0.003 RMSE: 1.139
# Reg-LFM: ite: 49; diff: 0.002 RMSE: 1.137
# Reg-LFM: ite: 50; diff: 0.002 RMSE: 1.135
# Reg-LFM: ite: 51; diff: 0.002 RMSE: 1.132
# Reg-LFM: ite: 52; diff: 0.002 RMSE: 1.130
# Reg-LFM: ite: 53; diff: 0.002 RMSE: 1.128
# Reg-LFM: ite: 54; diff: 0.002 RMSE: 1.126
# Reg-LFM: ite: 55; diff: 0.002 RMSE: 1.125
# Reg-LFM: ite: 56; diff: 0.002 RMSE: 1.123
# Reg-LFM: ite: 57; diff: 0.002 RMSE: 1.121
# Reg-LFM: ite: 58; diff: 0.002 RMSE: 1.120
# Reg-LFM: ite: 59; diff: 0.002 RMSE: 1.118
# Reg-LFM: ite: 60; diff: 0.001 RMSE: 1.117
# Reg-LFM: ite: 61; diff: 0.001 RMSE: 1.115
# Reg-LFM: ite: 62; diff: 0.001 RMSE: 1.114
# Reg-LFM: ite: 63; diff: 0.001 RMSE: 1.113
# Reg-LFM: ite: 64; diff: 0.001 RMSE: 1.111
# Reg-LFM: ite: 65; diff: 0.001 RMSE: 1.110
# Reg-LFM: ite: 66; diff: 0.001 RMSE: 1.109
# Reg-LFM: ite: 67; diff: 0.001 RMSE: 1.108
# Reg-LFM: ite: 68; diff: 0.001 RMSE: 1.107
# Reg-LFM: ite: 69; diff: 0.001 RMSE: 1.106
# Reg-LFM: ite: 70; diff: 0.001 RMSE: 1.105
# Reg-LFM: ite: 71; diff: 0.001 RMSE: 1.104
# Reg-LFM: ite: 72; diff: 0.001 RMSE: 1.103
# Reg-LFM: ite: 73; diff: 0.001 RMSE: 1.102
# Reg-LFM: ite: 74; diff: 0.001 RMSE: 1.102
# Reg-LFM: ite: 75; diff: 0.001 RMSE: 1.101
# Reg-LFM: ite: 76; diff: 0.001 RMSE: 1.100
# Reg-LFM: ite: 77; diff: 0.001 RMSE: 1.099
# Reg-LFM: ite: 78; diff: 0.001 RMSE: 1.099
# Reg-LFM: ite: 79; diff: 0.001 RMSE: 1.098
# Reg-LFM: ite: 80; diff: 0.001 RMSE: 1.097
# Reg-LFM: ite: 81; diff: 0.001 RMSE: 1.097
# Reg-LFM: ite: 82; diff: 0.001 RMSE: 1.096
# Reg-LFM: ite: 83; diff: 0.001 RMSE: 1.096
# Reg-LFM: ite: 84; diff: 0.001 RMSE: 1.095
# Reg-LFM: ite: 85; diff: 0.001 RMSE: 1.094
# Reg-LFM: ite: 86; diff: 0.001 RMSE: 1.094
# Reg-LFM: ite: 87; diff: 0.001 RMSE: 1.093
# Reg-LFM: ite: 88; diff: 0.000 RMSE: 1.093
# Reg-LFM: ite: 89; diff: 0.000 RMSE: 1.092
# Reg-LFM: ite: 90; diff: 0.000 RMSE: 1.092
# Reg-LFM: ite: 91; diff: 0.000 RMSE: 1.092
# Reg-LFM: ite: 92; diff: 0.000 RMSE: 1.091
# Reg-LFM: ite: 93; diff: 0.000 RMSE: 1.091
# Reg-LFM: ite: 94; diff: 0.000 RMSE: 1.090
# Reg-LFM: ite: 95; diff: 0.000 RMSE: 1.090
# Reg-LFM: ite: 96; diff: 0.000 RMSE: 1.090
# Reg-LFM: ite: 97; diff: 0.000 RMSE: 1.089
# Reg-LFM: ite: 98; diff: 0.000 RMSE: 1.089
# Reg-LFM: ite: 99; diff: 0.000 RMSE: 1.088
# Reg-LFM: ite: 100; diff: 0.000 RMSE: 1.088
# Reg-LFM: ite: 101; diff: 0.000 RMSE: 1.088
# Reg-LFM: ite: 102; diff: 0.000 RMSE: 1.087
# Reg-LFM: ite: 103; diff: 0.000 RMSE: 1.087
# Reg-LFM: ite: 104; diff: 0.000 RMSE: 1.087
# Reg-LFM: ite: 105; diff: 0.000 RMSE: 1.087
# Reg-LFM: ite: 106; diff: 0.000 RMSE: 1.086
# Reg-LFM: ite: 107; diff: 0.000 RMSE: 1.086
# Reg-LFM: ite: 108; diff: 0.000 RMSE: 1.086
# Reg-LFM: ite: 109; diff: 0.000 RMSE: 1.085
# Reg-LFM: ite: 110; diff: 0.000 RMSE: 1.085
# Reg-LFM: ite: 111; diff: 0.000 RMSE: 1.085
# Reg-LFM: ite: 112; diff: 0.000 RMSE: 1.085
# Reg-LFM: ite: 113; diff: 0.000 RMSE: 1.085
# Reg-LFM: ite: 114; diff: 0.000 RMSE: 1.084
# Reg-LFM: ite: 115; diff: 0.000 RMSE: 1.084
# Reg-LFM: ite: 116; diff: 0.000 RMSE: 1.084
# Reg-LFM: ite: 117; diff: 0.000 RMSE: 1.084
# Reg-LFM: ite: 118; diff: 0.000 RMSE: 1.083
# Reg-LFM: ite: 119; diff: 0.000 RMSE: 1.083
# Reg-LFM: ite: 120; diff: 0.000 RMSE: 1.083
# Reg-LFM: ite: 121; diff: 0.000 RMSE: 1.083
# Reg-LFM: ite: 122; diff: 0.000 RMSE: 1.083
# Reg-LFM: ite: 123; diff: 0.000 RMSE: 1.082
# Reg-LFM: ite: 124; diff: 0.000 RMSE: 1.082
# Reg-LFM: ite: 125; diff: 0.000 RMSE: 1.082
# Reg-LFM: ite: 126; diff: 0.000 RMSE: 1.082
# Reg-LFM: ite: 127; diff: 0.000 RMSE: 1.082
# Reg-LFM: ite: 128; diff: 0.000 RMSE: 1.082
# Reg-LFM: ite: 129; diff: 0.000 RMSE: 1.081
# Reg-LFM: ite: 130; diff: 0.000 RMSE: 1.081
# Reg-LFM: ite: 131; diff: 0.000 RMSE: 1.081
# Reg-LFM: ite: 132; diff: 0.000 RMSE: 1.081
# Reg-LFM: ite: 133; diff: 0.000 RMSE: 1.081
# Reg-LFM: ite: 134; diff: 0.000 RMSE: 1.081
# Reg-LFM: ite: 135; diff: 0.000 RMSE: 1.081
# Reg-LFM: ite: 136; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 137; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 138; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 139; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 140; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 141; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 142; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 143; diff: 0.000 RMSE: 1.080
# Reg-LFM: ite: 144; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 145; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 146; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 147; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 148; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 149; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 150; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 151; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 152; diff: 0.000 RMSE: 1.079
# Reg-LFM: ite: 153; diff: 0.000 RMSE: 1.078
# Reg-LFM: ite: 154; diff: 0.000 RMSE: 1.078

# %%
# Make your prediction
# pred_rating is an array of your prediction for `dtest`
pred_rating = pred


# submission
sub['rating'] = pred_rating
sub.to_csv('user_item_mean_LFMSGD.csv', index=False)

## Then just submit sub1.csv to the competition in Kaggle

# %%
pred
# Out:
# array([12.73030964, 17.99001373, 17.29738727, ..., 15.02221017,
#        23.32010652, 19.27083655])

# %%
t=2095
print_T(2095,temp_test_pair,pred_rating)
user_index=np.where(temp_test_pair[:,0]==temp_test_pair[t,0])[0]
item_index=pred_rating[user_index].argsort()[-5:][::-1]
list1=temp_test_pair[user_index,1][item_index]
list2=pred_rating[user_index][item_index]
result = pd.DataFrame(list(zip(list1, list2)), columns =['item', 'rating'])
print(result.sort_values(by='rating', ascending=False).to_string(index=False))
# Out:
# test_pair: ['D7F746' 'E36CD5']
# pred_rating: 3.699872847611943
#   item   rating
# 604A4B 6.904534
# A98D40 5.806089
# F89A64 5.675935
# E36CD5 3.699873
# 4BC7F1 3.223570

# %%
user_index
# Out:
# array([2095, 2178, 2506, 2637, 3580, 3772], dtype=int64)

# %%
user_index[item_index]
# Out:
# array([3580, 3772, 2637, 2095, 2178], dtype=int64)

# %%
pred_rating[user_index].argsort()[-5:][::-1]
# Out:
# array([4, 5, 3, 0, 1], dtype=int64)

# %%
pred_rating = adjust(pred_rating, 0, 15)
for i in range(len(pred_rating)):
    pred_rating[i]=round(pred_rating[i], 0) 
    
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_LFM_17_0.00035_int.csv', index=False)

# %%
pred_rating = adjust(pred_rating, 0, 15)
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_LFM_17_0.00035.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-4a6760ad6c5b> in <module>
#       1 pred_rating = adjust(pred_rating, 0, 15)
# ----> 2 sub['rating'] = pred_rating
#       3 sub.to_csv('predict/user_item_mean_LFM_17_0.00035.csv', index=False)
#
# NameError: name 'sub' is not defined

# %%
rating=pd.read_csv('user_mean_item mean_LFM.csv', usecols=['rating'])
pred_rating=rating[['rating']].values
sub = pd.read_csv('predict/sample_submission.csv')

# %%
def adjust(pred_rating, score_min, score_max):
    pred_rating_adjusted = pred_rating.copy()
    pred_rating_adjusted[pred_rating > score_max] = score_max
    pred_rating_adjusted[pred_rating < score_min] = score_min
    return pred_rating_adjusted
pred_rating = adjust(pred_rating, 0, 15)

# %%
temp=pred_rating

# %%
temp[1]%1
# Out:
# array([0.68099774])

# %%
for i in range(len(pred_rating)):
    if temp[i]%1<0.2 or temp[i]%1>0.8:
        pred_rating[i]=np.round(pred_rating[0], 0)

# %%
sub['rating'] = pred_rating
sub.to_csv('predict/user_item_mean_LFM_adjested.csv', index=False)
